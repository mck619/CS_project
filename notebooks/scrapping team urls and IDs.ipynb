# %%
import urllib2, sys
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
from IPython.core.display import HTML
import requests
import time
import cPickle as pkl

# %%
def get_team_ids(startDate, endDate):
    teams_url = 'https://www.hltv.org/stats/teams?startDate={0}&endDate={1}'.format(startDate, endDate)
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = urllib2.Request(teams_url,headers=hdr)
    page = urllib2.urlopen(req)
    soup = BeautifulSoup(page)
    
    teams = soup.find_all("td", class_='teamCol')
    return teams

# %%
teams = get_team_ids('2017-09-01', '2017-10-01')

# %%
team_info = pd.DataFrame(columns = ['team_name', 'url', 'team_id'])
for t in teams:
    team_name = t.find("a").text
    team_url = t.find("a")["href"]
    team_id = t.find("a")["href"].split("/")[3]
    team_info.loc[len(team_info),:] = team_name, team_url, team_id

# %%
len(team_info)
# Out:
# 90

# %%
team_info.to_csv('../../scrapped_data/team_info.csv')

# %%
team_info
# Out:
#            team_name                                                url  \
# 0               FaZe  /stats/teams/6667/FaZe?startDate=2017-09-01&en...
# 1              Flash  /stats/teams/7660/Flash?startDate=2017-09-01&e...
# 2         RESISTANCE  /stats/teams/7497/RESISTANCE?startDate=2017-09...
# 3               ViCi  /stats/teams/7606/ViCi?startDate=2017-09-01&en...
# 4               HAVU  /stats/teams/7865/HAVU?startDate=2017-09-01&en...
# 5              Recca  /stats/teams/7344/Recca?startDate=2017-09-01&e...
# 6            eXtatus  /stats/teams/6745/eXtatus?startDate=2017-09-01...
# 7              Kings  /stats/teams/8021/Kings?startDate=2017-09-01&e...
# 8                AGO  /stats/teams/8068/AGO?startDate=2017-09-01&end...
# 9             Cloud9  /stats/teams/5752/Cloud9?startDate=2017-09-01&...
# 10          Japaleno  /stats/teams/7144/Japaleno?startDate=2017-09-0...
# 11           Misfits  /stats/teams/7557/Misfits?startDate=2017-09-01...
# 12       Tempo Storm  /stats/teams/6118/Tempo%20Storm?startDate=2017...
# 13       HellRaisers  /stats/teams/5310/HellRaisers?startDate=2017-0...
# 14      Beyond.Maple  /stats/teams/8262/Beyond.Maple?startDate=2017-...
# 15               NRG  /stats/teams/6673/NRG?startDate=2017-09-01&end...
# 16    Space Soldiers  /stats/teams/5929/Space%20Soldiers?startDate=2...
# 17            Nemiga  /stats/teams/7969/Nemiga?startDate=2017-09-01&...
# 18         Immortals  /stats/teams/7010/Immortals?startDate=2017-09-...
# 19     Tainted Minds  /stats/teams/7517/Tainted%20Minds?startDate=20...
# 20             North  /stats/teams/7533/North?startDate=2017-09-01&e...
# 21            Chiefs  /stats/teams/6010/Chiefs?startDate=2017-09-01&...
# 22           Torqued  /stats/teams/5906/Torqued?startDate=2017-09-01...
# 23          dignitas  /stats/teams/5422/dignitas?startDate=2017-09-0...
# 24           Berzerk  /stats/teams/5121/Berzerk?startDate=2017-09-01...
# 25         Grayhound  /stats/teams/8008/Grayhound?startDate=2017-09-...
# 26              NASR  /stats/teams/8211/NASR?startDate=2017-09-01&en...
# 27         Signature  /stats/teams/6774/Signature?startDate=2017-09-...
# 28               BIG  /stats/teams/7532/BIG?startDate=2017-09-01&end...
# 29            Heroic  /stats/teams/7175/Heroic?startDate=2017-09-01&...
# ..               ...                                                ...
# 60            Legacy  /stats/teams/6468/Legacy?startDate=2017-09-01&...
# 61    EnVyUs Academy  /stats/teams/7856/EnVyUs%20Academy?startDate=2...
# 62            Gambit  /stats/teams/6651/Gambit?startDate=2017-09-01&...
# 63    Spirit Academy  /stats/teams/7900/Spirit%20Academy?startDate=2...
# 64     North Academy  /stats/teams/7713/North%20Academy?startDate=20...
# 65         Renegades  /stats/teams/6211/Renegades?startDate=2017-09-...
# 66               EPG  /stats/teams/7489/EPG?startDate=2017-09-01&end...
# 67          FlipSid3  /stats/teams/5988/FlipSid3?startDate=2017-09-0...
# 68            Denial  /stats/teams/4643/Denial?startDate=2017-09-01&...
# 69            Liquid  /stats/teams/5973/Liquid?startDate=2017-09-01&...
# 70              ARES  /stats/teams/8242/ARES?startDate=2017-09-01&en...
# 71       Rise Nation  /stats/teams/7924/Rise%20Nation?startDate=2017...
# 72        compLexity  /stats/teams/5005/compLexity?startDate=2017-09...
# 73               MAX  /stats/teams/8118/MAX?startDate=2017-09-01&end...
# 74             Rogue  /stats/teams/7157/Rogue?startDate=2017-09-01&e...
# 75           GODSENT  /stats/teams/6902/GODSENT?startDate=2017-09-01...
# 76            EnVyUs  /stats/teams/5991/EnVyUs?startDate=2017-09-01&...
# 77        Dark Sided  /stats/teams/7212/Dark%20Sided?startDate=2017-...
# 78             PRIDE  /stats/teams/6896/PRIDE?startDate=2017-09-01&e...
# 79         Fragsters  /stats/teams/6855/Fragsters?startDate=2017-09-...
# 80               SIN  /stats/teams/8321/SIN?startDate=2017-09-01&end...
# 81         undefined  /stats/teams/8064/undefined?startDate=2017-09-...
# 82             forZe  /stats/teams/8135/forZe?startDate=2017-09-01&e...
# 83             Ghost  /stats/teams/7801/Ghost?startDate=2017-09-01&e...
# 84  FRENCH CANADIANS  /stats/teams/7616/FRENCH%20CANADIANS?startDate...
# 85            Splyce  /stats/teams/6301/Splyce?startDate=2017-09-01&...
# 86        Virtus.pro  /stats/teams/5378/Virtus.pro?startDate=2017-09...
# 87                WG  /stats/teams/8143/WG?startDate=2017-09-01&endD...
# 88           Squared  /stats/teams/7669/Squared?startDate=2017-09-01...
# 89             AVANT  /stats/teams/5293/AVANT?startDate=2017-09-01&e...
#
#    team_id
# 0     6667
# 1     7660
# 2     7497
# 3     7606
# 4     7865
# 5     7344
# 6     6745
# 7     8021
# 8     8068
# 9     5752
# 10    7144
# 11    7557
# 12    6118
# 13    5310
# 14    8262
# 15    6673
# 16    5929
# 17    7969
# 18    7010
# 19    7517
# 20    7533
# 21    6010
# 22    5906
# 23    5422
# 24    5121
# 25    8008
# 26    8211
# 27    6774
# 28    7532
# 29    7175
# ..     ...
# 60    6468
# 61    7856
# 62    6651
# 63    7900
# 64    7713
# 65    6211
# 66    7489
# 67    5988
# 68    4643
# 69    5973
# 70    8242
# 71    7924
# 72    5005
# 73    8118
# 74    7157
# 75    6902
# 76    5991
# 77    7212
# 78    6896
# 79    6855
# 80    8321
# 81    8064
# 82    8135
# 83    7801
# 84    7616
# 85    6301
# 86    5378
# 87    8143
# 88    7669
# 89    5293
#
# [90 rows x 3 columns]
