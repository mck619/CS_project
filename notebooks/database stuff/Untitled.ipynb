# %%
from cspython.scraper import *

# %%
startDate = '2017-11-12'
endDate = '2017-11-14'
d = scrape_series_data(startDate, endDate, verbose=True, offset=6)
# Out:
# date based search
# https://www.hltv.org/results?offset=0&content=demo&startDate=2017-11-12&endDate=2017-11-14
# https://www.hltv.org/results?offset=100&content=demo&startDate=2017-11-12&endDate=2017-11-14
# https://www.hltv.org/matches/2317266/cloud9-vs-themongolz-iem-oakland-2017
# https://www.hltv.org/events/2956/iem-oakland-2017#MapPool
# https://www.hltv.org/matches/2317266/cloud9-vs-themongolz-iem-oakland-2017
# 2 - 0
# https://www.hltv.org/stats/matches/mapstatsid/57256/cloud9-vs-themongolz
# bad match: https://www.hltv.org/matches/2317266/cloud9-vs-themongolz-iem-oakland-2017
# https://www.hltv.org/matches/2317254/space-soldiers-vs-aaa-esea-mdl-season-26-europe
# https://www.hltv.org/events/3047/esea-mdl-season-26-europe#MapPool
# https://www.hltv.org/matches/2317254/space-soldiers-vs-aaa-esea-mdl-season-26-europe
# 2 - 0
# https://www.hltv.org/stats/matches/50642/space-soldiers-vs-aaa
# https://www.hltv.org/stats/matches/mapstatsid/57244/aaa-vs-space-soldiers
# ...
