# %%
import cspython.scraper
import pandas as pd
import numpy as np
import uuid
import sys
sys.setrecursionlimit(5000)

# %%
series = cspython.scraper.scrape_series_data('BIG', '2017-01-01', '2017-02-01', verbose=False)
# Out:
# match 0 done
# match 1 done
# match 2 done
# match 3 done
# match 4 done
# match 5 done
# match 6 done
# match 7 done

# %%
import cPickle as pkl
with open('test_pkl.pkl', 'wb') as f:
    pkl.dump(series, f)

# %% [markdown]
# Each element of list returned by scrape_series_data is a dictionary containing data 1 series played by the team. They are in reverse chornological order. The elements of each series dictionary are:
#
#     url:        the url on hltv of the Overview of the entire series
#     demo_url:   the url of the demo, hosted on hltv later
#     stats_url:  a url containing more detailed data about the data
#                 (the scrapped data from this page is contained in stats_data)
#     teams:      a dataframe containing the overall stats for each team in the series
#     vetos:      the vetos in chronological order
#     match_info: score and map name for each match
#     team_a_b:   this provides order to the teams and match_info scores

# %%
def match_score_dataframe(series, series_id=None):
    score = pd.DataFrame(columns = ['series_id', 'match_id', 'map', 'winner', series['team_a_b'][0], 
                                    series['team_a_b'][1]], 
                         index=range(len(series['match_info'])))
    for idx, match in enumerate(series['match_info']):
        
        map_name = match['map_name']
        score_a = int(match['scores'][0])
        score_b = int(match['scores'][1])
        if score_a > score_b:
            winner = series['team_a_b'][0]
        elif score_a < score_b:
            winner = series['team_a_b'][1]
        else:
            winner = 'draw'
        match_id = uuid.uuid4()
        score.loc[idx, :]  = series_id, match_id, map_name, winner, score_a, score_b
        
        
    score.loc[:,'match_num'] = range(1,len(score) + 1)
    
    return score

# %%
def round_by_round_dataframe(match_stats_data, map_name, match_id, series_id):
    winners = create_winner_column(match_stats_data['team_scores'])
    team_ending_df = create_team_ending_df(match_stats_data['team_endings'], winners)
    raw = pd.concat([team_ending_df, winners], axis=1)
    final = pd.DataFrame(columns = ['map', 'round_num', 'half'], index=raw.index)
    final.loc[:,'map'] = map_name
    final.loc[:,'round_num']=raw.index
    final.ix[:15, 'half'] = 1
    final.ix[15:, 'half'] = 2
    final.loc[:, 'match_id'] = match_id
    final.loc[:, 'series_id'] = series_id
    return pd.concat([final, raw], axis=1)

# %%
def create_winner_column(team_scores):
    team_a = pd.Series(team_scores['team_a']).apply(lambda x: x[0])
    team_b = pd.Series(team_scores['team_b']).apply(lambda x: x[0])
    raw_scores = pd.concat([team_a, team_b], axis=1)
    raw_scores = raw_scores.loc[(raw_scores.loc[:,0]!='')|(raw_scores.loc[:,1]!=''), :]
    
    team_a = raw_scores.iloc[0,0]
    team_b = raw_scores.iloc[0,1]
    
    raw_scores = raw_scores.iloc[1:,:]
    
    winner_col = pd.DataFrame(columns=['winner', team_a + '_wins', team_b + '_wins'], index=raw_scores.index)
    w_a=0
    w_b=0
    for idx, row in raw_scores.iterrows():
        if row.iloc[0]=='':
            winner = team_b
            w_b+=1
        else:
            winner = team_a
            w_a+=1
        winner_col.loc[idx,['winner', team_a + '_wins', team_b + '_wins']] = winner, w_a, w_b
    return winner_col

def create_team_ending_df(team_endings, winners):
    team_a_name, team_b_name = winners.columns[1][:-5], winners.columns[2][:-5]
    
    team_a = pd.Series(team_endings['team_a']).apply(lambda x: x[0])
    team_b = pd.Series(team_endings['team_b']).apply(lambda x: x[0])
    raw_endings = pd.concat([team_a, team_b], axis=1)
    raw_endings = raw_endings.loc[(raw_endings.loc[:,0]!='emptyHistory')|(raw_endings.loc[:,1]!='emptyHistory'), :]
    raw_endings = raw_endings.iloc[1:,:]
    endings = pd.DataFrame(columns=['ending', 'CT', 'T', 'side_winner'], index=raw_endings.index)
    
    if (('t_win' in team_a.iloc[:15]) 
        or ('ct_win' in team_a.iloc[:15])
        or ('ct_win' in team_a.iloc[15:]) 
        or ('t_win' in team_a.iloc[15:])):
        endings.ix[:15, 'T'] = team_b_name
        endings.ix[:15, 'CT'] = team_a_name
        endings.ix[15:, 'T'] = team_a_name
        endings.ix[15:, 'CT'] = team_b_name
    else:
        endings.ix[:15, 'T'] = team_a_name
        endings.ix[:15, 'CT'] = team_b_name
        endings.ix[15:, 'T'] = team_b_name
        endings.ix[15:, 'CT'] = team_a_name
        
    endings.loc[:,'ending'] = raw_endings.apply(lambda x: x.iloc[0] if x.iloc[0] != 'emptyHistory' else x.iloc[1], axis=1)
    endings.loc[:, 'side_winner'] = endings.apply(lambda x: 'T' if x.loc['T'] == winners.loc[x.name, 'winner'] else 'CT', axis=1)
    return endings

# %%
def series_overview_dataframe(all_series):
    all_series_overview = pd.DataFrame(columns=['id', 'date', 'team_a', 
                                                'team_b', 'url', 'stats_url',
                                               'demo_url'])
    for s in all_series:
        demo_url = s['demo_url']
        stats_url = s['stats_url']
        url = s['url']
        date = s['stats_data'][0]['match_time']
        team_a = s['team_a_b'][0]
        team_b = s['team_a_b'][1]
        serires_uuid = uuid.uuid4()
        all_series_overview.loc[len(all_series_overview), :]= (
        serires_uuid, date, team_a, team_b, url, stats_url, demo_url )
        
    return all_series_overview

# %%
def process_scrapped(all_series):
    overview = series_overview_dataframe(all_series)
    series_data = {}
     
    for s_id, s in zip(overview.id, all_series):
        match_overview = match_score_dataframe(s, s_id)
        map_pool = s['map_pool']
        vetos = s['vetos']
        matches=[]
        for m_id, m, map_name in zip(match_overview.match_id, s['stats_data'], match_overview.map):
            df = round_by_round_dataframe(m, map_name, m_id, s_id)
            matches.append(df)
            
        series_data[s_id] = {
                      'match_overview': match_overview,
                      'map_pool': map_pool,
                      'vetos': vetos,
                      'teams': s['teams'],
                      'matches':matches}
    return overview, series_data

# %%
overview, series_data = process_scrapped(series)

# %%
overview.to_pickle('BIG_overview.pkl')

# %%
import cPickle as pkl
with open('BIG_Series_data.pkl', 'wb') as f:
    pkl.dump(series_data, f)

# %%
round_by_round_dataframe(series[0]['stats_data'][0], 'Dust')
# Out:
#      map  round_num half         ending       CT        T side_winner  \
# 1   Dust          1    1          t_win  iNation      BIG           T
# 2   Dust          2    1  bomb_exploded  iNation      BIG           T
# 3   Dust          3    1  bomb_exploded  iNation      BIG           T
# 4   Dust          4    1          t_win  iNation      BIG           T
# 5   Dust          5    1         ct_win  iNation      BIG          CT
# 6   Dust          6    1         ct_win  iNation      BIG          CT
# 7   Dust          7    1   bomb_defused  iNation      BIG          CT
# 8   Dust          8    1         ct_win  iNation      BIG          CT
# 9   Dust          9    1         ct_win  iNation      BIG          CT
# 10  Dust         10    1         ct_win  iNation      BIG          CT
# 11  Dust         11    1         ct_win  iNation      BIG          CT
# 12  Dust         12    1         ct_win  iNation      BIG          CT
# 13  Dust         13    1         ct_win  iNation      BIG          CT
# 14  Dust         14    1         ct_win  iNation      BIG          CT
# 15  Dust         15    2          t_win      BIG  iNation          CT
# 16  Dust         16    2   bomb_defused      BIG  iNation          CT
# 17  Dust         17    2         ct_win      BIG  iNation          CT
# 18  Dust         18    2         ct_win      BIG  iNation          CT
# 19  Dust         19    2         ct_win      BIG  iNation          CT
# 20  Dust         20    2         ct_win      BIG  iNation          CT
# 21  Dust         21    2          t_win      BIG  iNation           T
# 22  Dust         22    2         ct_win      BIG  iNation          CT
# 23  Dust         23    2   bomb_defused      BIG  iNation          CT
# 24  Dust         24    2         ct_win      BIG  iNation          CT
# 25  Dust         25    2          t_win      BIG  iNation           T
# 26  Dust         26    2          t_win      BIG  iNation           T
# 27  Dust         27    2  bomb_exploded      BIG  iNation           T
# 28  Dust         28    2          t_win      BIG  iNation           T
# 29  Dust         29    2          t_win      BIG  iNation           T
#
#      winner BIG_wins iNation_wins
# 1       BIG        1            0
# 2       BIG        2            0
# 3       BIG        3            0
# 4       BIG        4            0
# 5   iNation        4            1
# 6   iNation        4            2
# 7   iNation        4            3
# 8   iNation        4            4
# 9   iNation        4            5
# 10  iNation        4            6
# 11  iNation        4            7
# 12  iNation        4            8
# 13  iNation        4            9
# 14  iNation        4           10
# 15      BIG        5           10
# 16      BIG        6           10
# 17      BIG        7           10
# 18      BIG        8           10
# 19      BIG        9           10
# 20      BIG       10           10
# 21  iNation       10           11
# 22      BIG       11           11
# 23      BIG       12           11
# 24      BIG       13           11
# 25  iNation       13           12
# 26  iNation       13           13
# 27  iNation       13           14
# 28  iNation       13           15
# 29  iNation       13           16

# %%
pd.__version__
# Out:
# u'0.18.1'

# %%
with open('BIG_Series_data.pkl', 'rb') as f:
    d = pkl.load(f)

# %%
d
# Out:
# {UUID('1ecd175d-500c-458e-8de3-33275bf21c00'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  1ecd175d-500c-458e-8de3-33275bf21c00  ed4f85e0-aa19-4345-906e-3166014c9927
#   1  1ecd175d-500c-458e-8de3-33275bf21c00  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#
#         map winner BIG Rogue  match_num
#   0  Mirage    BIG  16    12          1
#   1   Cache    BIG  16     6          2  ,
#   'matches': [       map  round_num half                              match_id  \
#    1   Mirage          1    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    2   Mirage          2    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    3   Mirage          3    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    4   Mirage          4    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    5   Mirage          5    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    6   Mirage          6    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    7   Mirage          7    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    8   Mirage          8    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    9   Mirage          9    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    10  Mirage         10    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    11  Mirage         11    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    12  Mirage         12    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    13  Mirage         13    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    14  Mirage         14    1  ed4f85e0-aa19-4345-906e-3166014c9927
#    15  Mirage         15    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    16  Mirage         16    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    17  Mirage         17    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    18  Mirage         18    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    19  Mirage         19    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    20  Mirage         20    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    21  Mirage         21    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    22  Mirage         22    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    23  Mirage         23    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    24  Mirage         24    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    25  Mirage         25    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    26  Mirage         26    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    27  Mirage         27    2  ed4f85e0-aa19-4345-906e-3166014c9927
#    28  Mirage         28    2  ed4f85e0-aa19-4345-906e-3166014c9927
#
#                                   series_id        ending     CT      T  \
#    1   1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused  Rogue    BIG
#    2   1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    3   1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    4   1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    5   1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    6   1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused  Rogue    BIG
#    7   1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused  Rogue    BIG
#    8   1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    9   1ecd175d-500c-458e-8de3-33275bf21c00         t_win  Rogue    BIG
#    10  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    11  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused  Rogue    BIG
#    12  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win  Rogue    BIG
#    13  1ecd175d-500c-458e-8de3-33275bf21c00         t_win  Rogue    BIG
#    14  1ecd175d-500c-458e-8de3-33275bf21c00     stopwatch  Rogue    BIG
#    15  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    16  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused    BIG  Rogue
#    17  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    18  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    19  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    20  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_defused    BIG  Rogue
#    21  1ecd175d-500c-458e-8de3-33275bf21c00         t_win    BIG  Rogue
#    22  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    23  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    24  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    25  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    26  1ecd175d-500c-458e-8de3-33275bf21c00        ct_win    BIG  Rogue
#    27  1ecd175d-500c-458e-8de3-33275bf21c00         t_win    BIG  Rogue
#    28  1ecd175d-500c-458e-8de3-33275bf21c00         t_win    BIG  Rogue
#
#       side_winner winner BIG_wins Rogue_wins
#    1            T    BIG        1          0
#    2            T    BIG        2          0
#    3            T    BIG        3          0
#    4            T    BIG        4          0
#    5            T    BIG        5          0
#    6            T    BIG        6          0
#    7            T    BIG        7          0
#    8            T    BIG        8          0
#    9           CT  Rogue        8          1
#    10           T    BIG        9          1
#    11           T    BIG       10          1
#    12           T    BIG       11          1
#    13          CT  Rogue       11          2
#    14           T    BIG       12          2
#    15          CT    BIG       13          2
#    16           T  Rogue       13          3
#    17           T  Rogue       13          4
#    18           T  Rogue       13          5
#    19           T  Rogue       13          6
#    20           T  Rogue       13          7
#    21          CT    BIG       14          7
#    22           T  Rogue       14          8
#    23           T  Rogue       14          9
#    24           T  Rogue       14         10
#    25           T  Rogue       14         11
#    26           T  Rogue       14         12
#    27          CT    BIG       15         12
#    28          CT    BIG       16         12  ,
#          map  round_num half                              match_id  \
#    1   Cache          1    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    2   Cache          2    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    3   Cache          3    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    4   Cache          4    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    5   Cache          5    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    6   Cache          6    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    7   Cache          7    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    8   Cache          8    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    9   Cache          9    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    10  Cache         10    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    11  Cache         11    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    12  Cache         12    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    13  Cache         13    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    14  Cache         14    1  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    15  Cache         15    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    16  Cache         16    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    17  Cache         17    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    18  Cache         18    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    19  Cache         19    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    20  Cache         20    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    21  Cache         21    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#    22  Cache         22    2  085ff490-959c-4bbd-ad18-7e9fdb29e6e8
#
#                                   series_id         ending     CT      T  \
#    1   1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    2   1ecd175d-500c-458e-8de3-33275bf21c00         ct_win  Rogue    BIG
#    3   1ecd175d-500c-458e-8de3-33275bf21c00         ct_win  Rogue    BIG
#    4   1ecd175d-500c-458e-8de3-33275bf21c00         ct_win  Rogue    BIG
#    5   1ecd175d-500c-458e-8de3-33275bf21c00   bomb_defused  Rogue    BIG
#    6   1ecd175d-500c-458e-8de3-33275bf21c00   bomb_defused  Rogue    BIG
#    7   1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    8   1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    9   1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    10  1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    11  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_exploded  Rogue    BIG
#    12  1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    13  1ecd175d-500c-458e-8de3-33275bf21c00          t_win  Rogue    BIG
#    14  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_exploded  Rogue    BIG
#    15  1ecd175d-500c-458e-8de3-33275bf21c00          t_win    BIG  Rogue
#    16  1ecd175d-500c-458e-8de3-33275bf21c00   bomb_defused    BIG  Rogue
#    17  1ecd175d-500c-458e-8de3-33275bf21c00   bomb_defused    BIG  Rogue
#    18  1ecd175d-500c-458e-8de3-33275bf21c00         ct_win    BIG  Rogue
#    19  1ecd175d-500c-458e-8de3-33275bf21c00         ct_win    BIG  Rogue
#    20  1ecd175d-500c-458e-8de3-33275bf21c00         ct_win    BIG  Rogue
#    21  1ecd175d-500c-458e-8de3-33275bf21c00  bomb_exploded    BIG  Rogue
#    22  1ecd175d-500c-458e-8de3-33275bf21c00         ct_win    BIG  Rogue
#
#       side_winner winner BIG_wins Rogue_wins
#    1            T    BIG        1          0
#    2           CT  Rogue        1          1
#    3           CT  Rogue        1          2
#    4           CT  Rogue        1          3
#    5           CT  Rogue        1          4
#    6           CT  Rogue        1          5
#    7            T    BIG        2          5
#    8            T    BIG        3          5
#    9            T    BIG        4          5
#    10           T    BIG        5          5
#    11           T    BIG        6          5
#    12           T    BIG        7          5
#    13           T    BIG        8          5
#    14           T    BIG        9          5
#    15          CT    BIG       10          5
#    16          CT    BIG       11          5
#    17          CT    BIG       12          5
#    18          CT    BIG       13          5
#    19          CT    BIG       14          5
#    20          CT    BIG       15          5
#    21           T  Rogue       15          6
#    22          CT    BIG       16          6  ],
#   'teams': [                                BIG    K-D  +/-   ADR   KAST  Rating2.0
#    0         Johannes 'nex' Maget  nex  46-30   16  90.0  84.0%       1.36
#    1   Kevin 'keev' Bartholomäus  keev  39-32    7  81.8  72.0%       1.24
#    2     Nikola 'LEGIJA' Ninić  LEGIJA  37-30    7  81.7  66.0%       1.18
#    3  Johannes 'tabseN' Wodarz  tabseN  38-33    5  80.5  66.0%       1.16
#    4        Fatih 'gob b' Dayik  gob b  24-30   -6  64.8  68.0%       0.96,
#                                   Rogue    K-D  +/-   ADR   KAST  Rating2.0
#    0  Jesper 'TENZKI' Plougmann  TENZKI  45-34   11  90.0  68.0%       1.27
#    1     Casper 'cadiaN' Møller  cadiaN  33-36   -3  72.4  60.0%       0.91
#    2    Viktor 'v1c7oR' Dyankov  v1c7oR  19-39  -20  58.4  72.0%       0.81
#    3  Kamen 'bubble' Kostadinov  bubble  28-38  -10  67.1  64.0%       0.80
#    4      Nicolai 'glace' Jensen  glace  30-38   -8  66.0  62.0%       0.79],
#   'vetos': [u'1. Rogue removed Cobblestone',
#    u'2. BIG removed Train',
#    u'3. Rogue picked Mirage',
#    u'4. BIG picked Cache',
#    u'5. Rogue removed Overpass',
#    u'6. BIG removed Nuke',
#    u'7. Dust2 was left over']},
#  UUID('3081c02d-2747-4979-bec6-b835d1e69dd6'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  3081c02d-2747-4979-bec6-b835d1e69dd6  7ea466ec-4f9c-4855-94b4-e0e36e311665
#
#        map winner BIG iGame.com  match_num
#   0  Dust2    BIG  16         8          1  ,
#   'matches': [      map  round_num half                              match_id  \
#    1   Dust2          1    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    2   Dust2          2    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    3   Dust2          3    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    4   Dust2          4    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    5   Dust2          5    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    6   Dust2          6    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    7   Dust2          7    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    8   Dust2          8    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    9   Dust2          9    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    10  Dust2         10    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    11  Dust2         11    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    12  Dust2         12    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    13  Dust2         13    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    14  Dust2         14    1  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    15  Dust2         15    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    16  Dust2         16    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    17  Dust2         17    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    18  Dust2         18    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    19  Dust2         19    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    20  Dust2         20    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    21  Dust2         21    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    22  Dust2         22    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    23  Dust2         23    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#    24  Dust2         24    2  7ea466ec-4f9c-4855-94b4-e0e36e311665
#
#                                   series_id         ending         CT          T  \
#    1   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    2   3081c02d-2747-4979-bec6-b835d1e69dd6   bomb_defused  iGame.com        BIG
#    3   3081c02d-2747-4979-bec6-b835d1e69dd6  bomb_exploded  iGame.com        BIG
#    4   3081c02d-2747-4979-bec6-b835d1e69dd6  bomb_exploded  iGame.com        BIG
#    5   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    6   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    7   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    8   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    9   3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    10  3081c02d-2747-4979-bec6-b835d1e69dd6   bomb_defused  iGame.com        BIG
#    11  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    12  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    13  3081c02d-2747-4979-bec6-b835d1e69dd6          t_win  iGame.com        BIG
#    14  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win  iGame.com        BIG
#    15  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win        BIG  iGame.com
#    16  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win        BIG  iGame.com
#    17  3081c02d-2747-4979-bec6-b835d1e69dd6   bomb_defused        BIG  iGame.com
#    18  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win        BIG  iGame.com
#    19  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win        BIG  iGame.com
#    20  3081c02d-2747-4979-bec6-b835d1e69dd6          t_win        BIG  iGame.com
#    21  3081c02d-2747-4979-bec6-b835d1e69dd6          t_win        BIG  iGame.com
#    22  3081c02d-2747-4979-bec6-b835d1e69dd6          t_win        BIG  iGame.com
#    23  3081c02d-2747-4979-bec6-b835d1e69dd6         ct_win        BIG  iGame.com
#    24  3081c02d-2747-4979-bec6-b835d1e69dd6          t_win        BIG  iGame.com
#
#       side_winner     winner BIG_wins iGame.com_wins
#    1            T        BIG        1              0
#    2            T        BIG        2              0
#    3           CT  iGame.com        2              1
#    4           CT  iGame.com        2              2
#    5            T        BIG        3              2
#    6            T        BIG        4              2
#    7            T        BIG        5              2
#    8            T        BIG        6              2
#    9            T        BIG        7              2
#    10           T        BIG        8              2
#    11           T        BIG        9              2
#    12           T        BIG       10              2
#    13          CT  iGame.com       10              3
#    14           T        BIG       11              3
#    15          CT        BIG       12              3
#    16           T  iGame.com       12              4
#    17           T  iGame.com       12              5
#    18           T  iGame.com       12              6
#    19           T  iGame.com       12              7
#    20          CT        BIG       13              7
#    21          CT        BIG       14              7
#    22          CT        BIG       15              7
#    23           T  iGame.com       15              8
#    24          CT        BIG       16              8  ],
#   'teams': [                                BIG    K-D  +/-    ADR   KAST  Rating2.0
#    0         Johannes 'nex' Maget  nex  24-11   13  111.5  75.0%       1.56
#    1  Johannes 'tabseN' Wodarz  tabseN  16-18   -2   87.4  83.3%       1.23
#    2        Fatih 'gob b' Dayik  gob b  20-15    5   77.1  62.5%       1.18
#    3   Kevin 'keev' Bartholomäus  keev  17-13    4   70.3  70.8%       1.17
#    4     Nikola 'LEGIJA' Ninić  LEGIJA  17-12    5   71.0  66.7%       1.16,
#                                 iGame.com    K-D  +/-   ADR   KAST  Rating2.0
#    0  Saku 'SAGGERTON' Jokinen  SAGGERTON  16-18   -2  76.9  58.3%       0.95
#    1           Juho 'juho' Lampinen  juho  18-19   -1  78.4  62.5%       0.94
#    2                 Eetu 'sAw' Saha  sAw  14-18   -4  57.5  66.7%       0.84
#    3       Sami 'xseveN' Laasanen  xseveN  11-18   -7  65.5  70.8%       0.73
#    4          Lasse 'ZOREE' Uronen  ZOREE  10-22  -12  51.8  50.0%       0.63],
#   'vetos': [u'1. BIG removed Nuke',
#    u'2. iGame.com removed Mirage',
#    u'3. BIG removed Train',
#    u'4. iGame.com removed Cache',
#    u'5. BIG removed Overpass',
#    u'6. iGame.com removed Cobblestone',
#    u'7. Dust2 was left over']},
#  UUID('3fb3fbd0-0812-4513-a7cd-450c72facd47'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  3fb3fbd0-0812-4513-a7cd-450c72facd47  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#   1  3fb3fbd0-0812-4513-a7cd-450c72facd47  3091275e-1270-458f-9dfc-44b1e1850640
#
#        map    winner FlipSid3 BIG  match_num
#   0  Cache  FlipSid3       16  11          1
#   1  Train  FlipSid3       16  11          2  ,
#   'matches': [      map  round_num half                              match_id  \
#    1   Cache          1    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    2   Cache          2    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    3   Cache          3    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    4   Cache          4    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    5   Cache          5    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    6   Cache          6    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    7   Cache          7    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    8   Cache          8    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    9   Cache          9    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    10  Cache         10    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    11  Cache         11    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    12  Cache         12    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    13  Cache         13    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    14  Cache         14    1  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    15  Cache         15    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    16  Cache         16    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    17  Cache         17    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    18  Cache         18    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    19  Cache         19    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    20  Cache         20    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    21  Cache         21    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    22  Cache         22    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    23  Cache         23    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    24  Cache         24    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    25  Cache         25    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    26  Cache         26    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#    27  Cache         27    2  41e216e0-65e0-4a9b-9bfb-ac68d127475b
#
#                                   series_id         ending        CT         T  \
#    1   3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused       BIG  FlipSid3
#    2   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    3   3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded       BIG  FlipSid3
#    4   3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused       BIG  FlipSid3
#    5   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    6   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    7   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    8   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    9   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    10  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    11  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    12  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    13  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    14  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    15  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    16  3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused  FlipSid3       BIG
#    17  3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused  FlipSid3       BIG
#    18  3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded  FlipSid3       BIG
#    19  3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused  FlipSid3       BIG
#    20  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    21  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    22  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    23  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    24  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    25  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    26  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    27  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#
#       side_winner    winner FlipSid3_wins BIG_wins
#    1           CT       BIG             0        1
#    2           CT       BIG             0        2
#    3            T  FlipSid3             1        2
#    4           CT       BIG             1        3
#    5            T  FlipSid3             2        3
#    6            T  FlipSid3             3        3
#    7            T  FlipSid3             4        3
#    8           CT       BIG             4        4
#    9           CT       BIG             4        5
#    10           T  FlipSid3             5        5
#    11           T  FlipSid3             6        5
#    12           T  FlipSid3             7        5
#    13          CT       BIG             7        6
#    14           T  FlipSid3             8        6
#    15          CT  FlipSid3             9        6
#    16          CT  FlipSid3            10        6
#    17          CT  FlipSid3            11        6
#    18           T       BIG            11        7
#    19          CT  FlipSid3            12        7
#    20          CT  FlipSid3            13        7
#    21          CT  FlipSid3            14        7
#    22           T       BIG            14        8
#    23          CT  FlipSid3            15        8
#    24           T       BIG            15        9
#    25           T       BIG            15       10
#    26           T       BIG            15       11
#    27          CT  FlipSid3            16       11  ,
#          map  round_num half                              match_id  \
#    1   Train          1    1  3091275e-1270-458f-9dfc-44b1e1850640
#    2   Train          2    1  3091275e-1270-458f-9dfc-44b1e1850640
#    3   Train          3    1  3091275e-1270-458f-9dfc-44b1e1850640
#    4   Train          4    1  3091275e-1270-458f-9dfc-44b1e1850640
#    5   Train          5    1  3091275e-1270-458f-9dfc-44b1e1850640
#    6   Train          6    1  3091275e-1270-458f-9dfc-44b1e1850640
#    7   Train          7    1  3091275e-1270-458f-9dfc-44b1e1850640
#    8   Train          8    1  3091275e-1270-458f-9dfc-44b1e1850640
#    9   Train          9    1  3091275e-1270-458f-9dfc-44b1e1850640
#    10  Train         10    1  3091275e-1270-458f-9dfc-44b1e1850640
#    11  Train         11    1  3091275e-1270-458f-9dfc-44b1e1850640
#    12  Train         12    1  3091275e-1270-458f-9dfc-44b1e1850640
#    13  Train         13    1  3091275e-1270-458f-9dfc-44b1e1850640
#    14  Train         14    1  3091275e-1270-458f-9dfc-44b1e1850640
#    15  Train         15    2  3091275e-1270-458f-9dfc-44b1e1850640
#    16  Train         16    2  3091275e-1270-458f-9dfc-44b1e1850640
#    17  Train         17    2  3091275e-1270-458f-9dfc-44b1e1850640
#    18  Train         18    2  3091275e-1270-458f-9dfc-44b1e1850640
#    19  Train         19    2  3091275e-1270-458f-9dfc-44b1e1850640
#    20  Train         20    2  3091275e-1270-458f-9dfc-44b1e1850640
#    21  Train         21    2  3091275e-1270-458f-9dfc-44b1e1850640
#    22  Train         22    2  3091275e-1270-458f-9dfc-44b1e1850640
#    23  Train         23    2  3091275e-1270-458f-9dfc-44b1e1850640
#    24  Train         24    2  3091275e-1270-458f-9dfc-44b1e1850640
#    25  Train         25    2  3091275e-1270-458f-9dfc-44b1e1850640
#    26  Train         26    2  3091275e-1270-458f-9dfc-44b1e1850640
#    27  Train         27    2  3091275e-1270-458f-9dfc-44b1e1850640
#
#                                   series_id         ending        CT         T  \
#    1   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    2   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    3   3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused       BIG  FlipSid3
#    4   3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded       BIG  FlipSid3
#    5   3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded       BIG  FlipSid3
#    6   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    7   3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    8   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    9   3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    10  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    11  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    12  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win       BIG  FlipSid3
#    13  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    14  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win       BIG  FlipSid3
#    15  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    16  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    17  3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded  FlipSid3       BIG
#    18  3fb3fbd0-0812-4513-a7cd-450c72facd47          t_win  FlipSid3       BIG
#    19  3fb3fbd0-0812-4513-a7cd-450c72facd47   bomb_defused  FlipSid3       BIG
#    20  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    21  3fb3fbd0-0812-4513-a7cd-450c72facd47  bomb_exploded  FlipSid3       BIG
#    22  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    23  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    24  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    25  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    26  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#    27  3fb3fbd0-0812-4513-a7cd-450c72facd47         ct_win  FlipSid3       BIG
#
#       side_winner    winner FlipSid3_wins BIG_wins
#    1           CT       BIG             0        1
#    2           CT       BIG             0        2
#    3           CT       BIG             0        3
#    4            T  FlipSid3             1        3
#    5            T  FlipSid3             2        3
#    6            T  FlipSid3             3        3
#    7           CT       BIG             3        4
#    8            T  FlipSid3             4        4
#    9            T  FlipSid3             5        4
#    10           T  FlipSid3             6        4
#    11           T  FlipSid3             7        4
#    12           T  FlipSid3             8        4
#    13          CT       BIG             8        5
#    14          CT       BIG             8        6
#    15           T       BIG             8        7
#    16           T       BIG             8        8
#    17           T       BIG             8        9
#    18           T       BIG             8       10
#    19          CT  FlipSid3             9       10
#    20          CT  FlipSid3            10       10
#    21           T       BIG            10       11
#    22          CT  FlipSid3            11       11
#    23          CT  FlipSid3            12       11
#    24          CT  FlipSid3            13       11
#    25          CT  FlipSid3            14       11
#    26          CT  FlipSid3            15       11
#    27          CT  FlipSid3            16       11  ],
#   'teams': [                                  FlipSid3    K-D  +/-    ADR   KAST  \
#    0  Denis 'electronic' Sharipov  electronic  54-31   23  102.2  81.5%
#    1    Yegor 'markeloff' Markelov  markeloff  38-30    8   78.6  74.1%
#    2      Jan 'wayLander' Rahkonen  wayLander  40-37    3   80.3  66.7%
#    3        Andrey 'B1ad3' Gorodenskiy  B1ad3  36-38   -2   70.6  77.8%
#    4     Georgi 'WorldEdit' Yaskin  WorldEdit  39-35    4   73.1  74.1%
#
#       Rating2.0
#    0       1.57
#    1       1.16
#    2       1.15
#    3       1.10
#    4       1.07  ,
#                                    BIG    K-D  +/-   ADR   KAST  Rating2.0
#    0  Johannes 'tabseN' Wodarz  tabseN  44-39    5  91.4  68.5%       1.21
#    1         Johannes 'nex' Maget  nex  36-44   -8  73.9  63.0%       0.86
#    2     Nikola 'LEGIJA' Ninić  LEGIJA  30-42  -12  61.2  66.7%       0.80
#    3        Fatih 'gob b' Dayik  gob b  27-41  -14  69.0  63.0%       0.80
#    4   Kevin 'keev' Bartholomäus  keev  33-42   -9  64.4  61.1%       0.79],
#   'vetos': [u'1. BIG removed Nuke',
#    u'2. FlipSid3 removed Dust2',
#    u'3. BIG picked Cache',
#    u'4. FlipSid3 picked Train',
#    u'5. BIG removed Mirage',
#    u'6. FlipSid3 removed Cobblestone',
#    u'7. Overpass was left over']},
#  UUID('53e95bb9-91bd-42d8-b7cf-59c4bdc2293b'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b  ee29da65-abc1-4e98-82ef-fe2e72a36460
#
#           map    winner FlipSid3 BIG  match_num
#   0  Overpass  FlipSid3       16  11          1  ,
#   'matches': [         map  round_num half                              match_id  \
#    1   Overpass          1    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    2   Overpass          2    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    3   Overpass          3    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    4   Overpass          4    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    5   Overpass          5    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    6   Overpass          6    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    7   Overpass          7    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    8   Overpass          8    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    9   Overpass          9    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    10  Overpass         10    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    11  Overpass         11    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    12  Overpass         12    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    13  Overpass         13    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    14  Overpass         14    1  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    15  Overpass         15    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    16  Overpass         16    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    17  Overpass         17    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    18  Overpass         18    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    19  Overpass         19    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    20  Overpass         20    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    21  Overpass         21    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    22  Overpass         22    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    23  Overpass         23    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    24  Overpass         24    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    25  Overpass         25    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    26  Overpass         26    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#    27  Overpass         27    2  ee29da65-abc1-4e98-82ef-fe2e72a36460
#
#                                   series_id         ending        CT         T  \
#    1   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    2   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    3   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    4   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    5   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    6   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b  bomb_exploded       BIG  FlipSid3
#    7   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b  bomb_exploded       BIG  FlipSid3
#    8   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win       BIG  FlipSid3
#    9   53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    10  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    11  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win       BIG  FlipSid3
#    12  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    13  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    14  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win       BIG  FlipSid3
#    15  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win  FlipSid3       BIG
#    16  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    17  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    18  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    19  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    20  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    21  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b   bomb_defused  FlipSid3       BIG
#    22  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win  FlipSid3       BIG
#    23  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win  FlipSid3       BIG
#    24  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    25  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    26  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b          t_win  FlipSid3       BIG
#    27  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b         ct_win  FlipSid3       BIG
#
#       side_winner    winner FlipSid3_wins BIG_wins
#    1            T  FlipSid3             1        0
#    2            T  FlipSid3             2        0
#    3            T  FlipSid3             3        0
#    4            T  FlipSid3             4        0
#    5            T  FlipSid3             5        0
#    6            T  FlipSid3             6        0
#    7            T  FlipSid3             7        0
#    8           CT       BIG             7        1
#    9            T  FlipSid3             8        1
#    10           T  FlipSid3             9        1
#    11          CT       BIG             9        2
#    12           T  FlipSid3            10        2
#    13           T  FlipSid3            11        2
#    14           T  FlipSid3            12        2
#    15           T       BIG            12        3
#    16           T       BIG            12        4
#    17           T       BIG            12        5
#    18           T       BIG            12        6
#    19           T       BIG            12        7
#    20           T       BIG            12        8
#    21          CT  FlipSid3            13        8
#    22          CT  FlipSid3            14        8
#    23          CT  FlipSid3            15        8
#    24           T       BIG            15        9
#    25           T       BIG            15       10
#    26           T       BIG            15       11
#    27          CT  FlipSid3            16       11  ],
#   'teams': [                                  FlipSid3    K-D  +/-   ADR   KAST  Rating2.0
#    0  Denis 'electronic' Sharipov  electronic  27-16   11  97.8  77.8%       1.51
#    1        Andrey 'B1ad3' Gorodenskiy  B1ad3  20-16    4  91.5  77.8%       1.42
#    2     Georgi 'WorldEdit' Yaskin  WorldEdit  20-17    3  84.3  74.1%       1.19
#    3      Jan 'wayLander' Rahkonen  wayLander  18-19   -1  75.1  66.7%       1.06
#    4    Yegor 'markeloff' Markelov  markeloff  15-17   -2  60.0  66.7%       0.89,
#                                    BIG    K-D  +/-   ADR   KAST  Rating2.0
#    0  Johannes 'tabseN' Wodarz  tabseN  19-22   -3  79.4  59.3%       1.04
#    1         Johannes 'nex' Maget  nex  19-19    0  75.3  63.0%       0.96
#    2        Fatih 'gob b' Dayik  gob b  19-19    0  62.4  66.7%       0.91
#    3   Kevin 'keev' Bartholomäus  keev  17-21   -4  66.5  51.9%       0.81
#    4     Nikola 'LEGIJA' Ninić  LEGIJA  11-19   -8  73.8  59.3%       0.80],
#   'vetos': [u'1. FlipSid3 removed Dust2',
#    u'2. BIG removed Train',
#    u'3. FlipSid3 removed Cache',
#    u'4. BIG removed Nuke',
#    u'5. FlipSid3 removed Cobblestone',
#    u'6. BIG removed Mirage',
#    u'7. Overpass was left over']},
#  UUID('6896338b-bacb-4405-aaf2-3b79f8b323a3'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  6896338b-bacb-4405-aaf2-3b79f8b323a3  dc833162-943d-4a55-bbf9-504596caca68
#   1  6896338b-bacb-4405-aaf2-3b79f8b323a3  ee840c3a-40a1-41ae-a654-3efd39d0084a
#   2  6896338b-bacb-4405-aaf2-3b79f8b323a3  2026810a-58de-45ff-b564-fb5d6b21bac3
#
#              map  winner Heroic BIG  match_num
#   0        Train  Heroic     16   4          1
#   1        Dust2     BIG     14  16          2
#   2  Cobblestone     BIG      9  16          3  ,
#   'matches': [      map  round_num half                              match_id  \
#    1   Train          1    1  dc833162-943d-4a55-bbf9-504596caca68
#    2   Train          2    1  dc833162-943d-4a55-bbf9-504596caca68
#    3   Train          3    1  dc833162-943d-4a55-bbf9-504596caca68
#    4   Train          4    1  dc833162-943d-4a55-bbf9-504596caca68
#    5   Train          5    1  dc833162-943d-4a55-bbf9-504596caca68
#    6   Train          6    1  dc833162-943d-4a55-bbf9-504596caca68
#    7   Train          7    1  dc833162-943d-4a55-bbf9-504596caca68
#    8   Train          8    1  dc833162-943d-4a55-bbf9-504596caca68
#    9   Train          9    1  dc833162-943d-4a55-bbf9-504596caca68
#    10  Train         10    1  dc833162-943d-4a55-bbf9-504596caca68
#    11  Train         11    1  dc833162-943d-4a55-bbf9-504596caca68
#    12  Train         12    1  dc833162-943d-4a55-bbf9-504596caca68
#    13  Train         13    1  dc833162-943d-4a55-bbf9-504596caca68
#    14  Train         14    1  dc833162-943d-4a55-bbf9-504596caca68
#    15  Train         15    2  dc833162-943d-4a55-bbf9-504596caca68
#    16  Train         16    2  dc833162-943d-4a55-bbf9-504596caca68
#    17  Train         17    2  dc833162-943d-4a55-bbf9-504596caca68
#    18  Train         18    2  dc833162-943d-4a55-bbf9-504596caca68
#    19  Train         19    2  dc833162-943d-4a55-bbf9-504596caca68
#    20  Train         20    2  dc833162-943d-4a55-bbf9-504596caca68
#
#                                   series_id         ending      CT       T  \
#    1   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    2   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    3   6896338b-bacb-4405-aaf2-3b79f8b323a3  bomb_exploded     BIG  Heroic
#    4   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    5   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    6   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    7   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    8   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    9   6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    10  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    11  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    12  6896338b-bacb-4405-aaf2-3b79f8b323a3  bomb_exploded     BIG  Heroic
#    13  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    14  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    15  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win  Heroic     BIG
#    16  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win  Heroic     BIG
#    17  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win  Heroic     BIG
#    18  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win  Heroic     BIG
#    19  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win  Heroic     BIG
#    20  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win  Heroic     BIG
#
#       side_winner  winner Heroic_wins BIG_wins
#    1           CT     BIG           0        1
#    2           CT     BIG           0        2
#    3            T  Heroic           1        2
#    4            T  Heroic           2        2
#    5            T  Heroic           3        2
#    6            T  Heroic           4        2
#    7            T  Heroic           5        2
#    8            T  Heroic           6        2
#    9            T  Heroic           7        2
#    10           T  Heroic           8        2
#    11          CT     BIG           8        3
#    12           T  Heroic           9        3
#    13           T  Heroic          10        3
#    14          CT     BIG          10        4
#    15          CT  Heroic          11        4
#    16          CT  Heroic          12        4
#    17          CT  Heroic          13        4
#    18          CT  Heroic          14        4
#    19          CT  Heroic          15        4
#    20          CT  Heroic          16        4  ,
#          map  round_num half                              match_id  \
#    1   Dust2          1    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    2   Dust2          2    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    3   Dust2          3    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    4   Dust2          4    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    5   Dust2          5    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    6   Dust2          6    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    7   Dust2          7    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    8   Dust2          8    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    9   Dust2          9    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    10  Dust2         10    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    11  Dust2         11    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    12  Dust2         12    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    13  Dust2         13    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    14  Dust2         14    1  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    15  Dust2         15    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    16  Dust2         16    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    17  Dust2         17    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    18  Dust2         18    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    19  Dust2         19    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    20  Dust2         20    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    21  Dust2         21    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    22  Dust2         22    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    23  Dust2         23    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    24  Dust2         24    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    25  Dust2         25    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    26  Dust2         26    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    27  Dust2         27    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    28  Dust2         28    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    29  Dust2         29    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#    30  Dust2         30    2  ee840c3a-40a1-41ae-a654-3efd39d0084a
#
#                                   series_id         ending      CT       T  \
#    1   6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    2   6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    3   6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    4   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    5   6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    6   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    7   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    8   6896338b-bacb-4405-aaf2-3b79f8b323a3  bomb_exploded     BIG  Heroic
#    9   6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused     BIG  Heroic
#    10  6896338b-bacb-4405-aaf2-3b79f8b323a3  bomb_exploded     BIG  Heroic
#    11  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    12  6896338b-bacb-4405-aaf2-3b79f8b323a3  bomb_exploded     BIG  Heroic
#    13  6896338b-bacb-4405-aaf2-3b79f8b323a3         ct_win     BIG  Heroic
#    14  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win     BIG  Heroic
#    15  6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused  Heroic     BIG
#    16  6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused  Heroic     BIG
#    17  6896338b-bacb-4405-aaf2-3b79f8b323a3   bomb_defused  Heroic     BIG
#    18  6896338b-bacb-4405-aaf2-3b79f8b323a3          t_win  Heroic     BIG
# ...
#    20          BIG          CT  mousesports                9       11
#    21          BIG          CT  mousesports               10       11
#    22          BIG          CT  mousesports               11       11
#    23          BIG          CT  mousesports               12       11
#    24          BIG          CT  mousesports               13       11
#    25          BIG          CT  mousesports               14       11
#    26          BIG          CT  mousesports               15       11
#    27          BIG          CT  mousesports               16       11  ],
#   'teams': [                               mousesports    K-D  +/-   ADR   KAST  Rating2.0
#    0                Nikola 'NiKo' Kovač  NiKo  68-55   13  85.5  72.9%       1.24
#    1            Timo 'Spiidi' Richter  Spiidi  67-52   15  83.3  75.3%       1.21
#    2              Denis 'denis' Howell  denis  56-60   -4  78.6  70.6%       1.07
#    3           Chris 'chrisJ' de Jong  chrisJ  60-54    6  70.7  70.6%       1.06
#    4  Christian 'loWel' Garcia Antoran  loWel  55-54    1  68.6  67.1%       0.99,
#                                    BIG    K-D  +/-    ADR   KAST  Rating2.0
#    0  Johannes 'tabseN' Wodarz  tabseN  73-62   11  102.1  70.6%       1.31
#    1     Nikola 'LEGIJA' Ninić  LEGIJA  56-63   -7   68.2  68.2%       0.92
#    2         Johannes 'nex' Maget  nex  53-61   -8   70.0  61.2%       0.88
#    3   Kevin 'keev' Bartholomäus  keev  48-57   -9   62.9  58.8%       0.85
#    4        Fatih 'gob b' Dayik  gob b  45-63  -18   64.7  65.9%       0.85],
#   'vetos': [u'1. BIG removed Train',
#    u'2. mousesports removed Nuke',
#    u'3. BIG picked Cobblestone',
#    u'4. mousesports picked Cache',
#    u'5. BIG removed Dust2',
#    u'6. mousesports removed Overpass',
#    u'7. Mirage was left over']},
#  UUID('f130d28e-adc9-42aa-bbed-d0b7688f474f'): {'map_pool': [u'Cache',
#    u'Dust2',
#    u'Mirage',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  f130d28e-adc9-42aa-bbed-d0b7688f474f  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#   1  f130d28e-adc9-42aa-bbed-d0b7688f474f  3093b1a4-6f6b-489f-8f9c-f81776919531
#
#        map winner Vega Squadron BIG  match_num
#   0  Dust2    BIG             7  16          1
#   1  Train    BIG            26  28          2  ,
#   'matches': [      map  round_num half                              match_id  \
#    1   Dust2          1    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    2   Dust2          2    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    3   Dust2          3    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    4   Dust2          4    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    5   Dust2          5    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    6   Dust2          6    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    7   Dust2          7    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    8   Dust2          8    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    9   Dust2          9    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    10  Dust2         10    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    11  Dust2         11    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    12  Dust2         12    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    13  Dust2         13    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    14  Dust2         14    1  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    15  Dust2         15    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    16  Dust2         16    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    17  Dust2         17    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    18  Dust2         18    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    19  Dust2         19    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    20  Dust2         20    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    21  Dust2         21    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    22  Dust2         22    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#    23  Dust2         23    2  5afc5023-2608-4039-9180-6bcfb8f6a8d5
#
#                                   series_id         ending             CT  \
#    1   f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused            BIG
#    2   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    3   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    4   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    5   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    6   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    7   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    8   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    9   f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    10  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    11  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    12  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    13  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    14  f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    15  f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused  Vega Squadron
#    16  f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win  Vega Squadron
#    17  f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused  Vega Squadron
#    18  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    19  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded  Vega Squadron
#    20  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    21  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    22  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded  Vega Squadron
#    23  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#
#                    T side_winner         winner Vega Squadron_wins BIG_wins
#    1   Vega Squadron          CT            BIG                  0        1
#    2   Vega Squadron          CT            BIG                  0        2
#    3   Vega Squadron          CT            BIG                  0        3
#    4   Vega Squadron          CT            BIG                  0        4
#    5   Vega Squadron          CT            BIG                  0        5
#    6   Vega Squadron          CT            BIG                  0        6
#    7   Vega Squadron          CT            BIG                  0        7
#    8   Vega Squadron          CT            BIG                  0        8
#    9   Vega Squadron           T  Vega Squadron                  1        8
#    10  Vega Squadron           T  Vega Squadron                  2        8
#    11  Vega Squadron           T  Vega Squadron                  3        8
#    12  Vega Squadron           T  Vega Squadron                  4        8
#    13  Vega Squadron           T  Vega Squadron                  5        8
#    14  Vega Squadron          CT            BIG                  5        9
#    15            BIG           T            BIG                  5       10
#    16            BIG          CT  Vega Squadron                  6       10
#    17            BIG          CT  Vega Squadron                  7       10
#    18            BIG           T            BIG                  7       11
#    19            BIG           T            BIG                  7       12
#    20            BIG           T            BIG                  7       13
#    21            BIG           T            BIG                  7       14
#    22            BIG           T            BIG                  7       15
#    23            BIG           T            BIG                  7       16  ,
#          map  round_num half                              match_id  \
#    1   Train          1    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    2   Train          2    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    3   Train          3    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    4   Train          4    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    5   Train          5    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    6   Train          6    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    7   Train          7    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    8   Train          8    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    9   Train          9    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    10  Train         10    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    11  Train         11    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    12  Train         12    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    13  Train         13    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    14  Train         14    1  3093b1a4-6f6b-489f-8f9c-f81776919531
#    15  Train         15    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    16  Train         16    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    17  Train         17    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    18  Train         18    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    19  Train         19    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    20  Train         20    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    21  Train         21    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    22  Train         22    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    23  Train         23    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    24  Train         24    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    25  Train         25    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    26  Train         26    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    27  Train         27    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    28  Train         28    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    29  Train         29    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#    30  Train         30    2  3093b1a4-6f6b-489f-8f9c-f81776919531
#
#                                   series_id         ending             CT  \
#    1   f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    2   f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    3   f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    4   f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    5   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    6   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    7   f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused            BIG
#    8   f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    9   f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win            BIG
#    10  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    11  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded            BIG
#    12  f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused            BIG
#    13  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    14  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win            BIG
#    15  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    16  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    17  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    18  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded  Vega Squadron
#    19  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    20  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    21  f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused  Vega Squadron
#    22  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    23  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded  Vega Squadron
#    24  f130d28e-adc9-42aa-bbed-d0b7688f474f  bomb_exploded  Vega Squadron
#    25  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    26  f130d28e-adc9-42aa-bbed-d0b7688f474f          t_win  Vega Squadron
#    27  f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win  Vega Squadron
#    28  f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win  Vega Squadron
#    29  f130d28e-adc9-42aa-bbed-d0b7688f474f   bomb_defused  Vega Squadron
#    30  f130d28e-adc9-42aa-bbed-d0b7688f474f         ct_win  Vega Squadron
#
#                    T side_winner         winner Vega Squadron_wins BIG_wins
#    1   Vega Squadron           T  Vega Squadron                  1        0
#    2   Vega Squadron           T  Vega Squadron                  2        0
#    3   Vega Squadron           T  Vega Squadron                  3        0
#    4   Vega Squadron           T  Vega Squadron                  4        0
#    5   Vega Squadron          CT            BIG                  4        1
#    6   Vega Squadron          CT            BIG                  4        2
#    7   Vega Squadron          CT            BIG                  4        3
#    8   Vega Squadron           T  Vega Squadron                  5        3
#    9   Vega Squadron          CT            BIG                  5        4
#    10  Vega Squadron           T  Vega Squadron                  6        4
#    11  Vega Squadron           T  Vega Squadron                  7        4
#    12  Vega Squadron          CT            BIG                  7        5
#    13  Vega Squadron           T  Vega Squadron                  8        5
#    14  Vega Squadron           T  Vega Squadron                  9        5
#    15            BIG          CT  Vega Squadron                 10        5
#    16            BIG           T            BIG                 10        6
#    17            BIG           T            BIG                 10        7
#    18            BIG           T            BIG                 10        8
#    19            BIG           T            BIG                 10        9
#    20            BIG           T            BIG                 10       10
#    21            BIG          CT  Vega Squadron                 11       10
#    22            BIG           T            BIG                 11       11
#    23            BIG           T            BIG                 11       12
#    24            BIG           T            BIG                 11       13
#    25            BIG           T            BIG                 11       14
#    26            BIG           T            BIG                 11       15
#    27            BIG          CT  Vega Squadron                 12       15
#    28            BIG          CT  Vega Squadron                 13       15
#    29            BIG          CT  Vega Squadron                 14       15
#    30            BIG          CT  Vega Squadron                 15       15  ],
#   'teams': [                          Vega Squadron    K-D  +/-   ADR   KAST  Rating2.0
#    0           Nikolay 'mir' Bityukov  mir  55-63   -8  80.0  70.1%       1.05
#    1  Sergey 'keshandr' Nikishin  keshandr  56-60   -4  74.9  63.6%       0.98
#    2              Dmitriy 'jR' Chervak  jR  53-54   -1  71.3  59.7%       0.97
#    3          Pavel 'hutji' Lashkov  hutji  49-61  -12  79.9  67.5%       0.95
#    4  Leonid 'chopper' Vishnyakov  chopper  37-58  -21  54.2  54.5%       0.72,
#                                    BIG    K-D  +/-    ADR   KAST  Rating2.0
#    0         Johannes 'nex' Maget  nex  80-47   33  103.9  81.8%       1.51
#    1   Kevin 'keev' Bartholomäus  keev  57-45   12   72.2  71.4%       1.21
#    2  Johannes 'tabseN' Wodarz  tabseN  61-55    6   76.7  68.8%       1.12
#    3        Fatih 'gob b' Dayik  gob b  53-52    1   79.3  76.6%       1.09
#    4     Nikola 'LEGIJA' Ninić  LEGIJA  44-51   -7   69.5  71.4%       0.96],
#   'vetos': [u'1. BIG removed Nuke',
#    u'2. Vega Squadron removed Cobblestone',
#    u'3. BIG picked Dust2',
#    u'4. Vega Squadron picked Train',
#    u'5. BIG removed Cache',
#    u'6. Vega Squadron removed Overpass',
#    u'7. Mirage was left over']}}

# %%
overview
# Out:
#                                      id                 date         team_a  \
# 0  9f427404-0a0f-42f3-a030-776cbb1ec929  2017-01-30 18:00:00            BIG
# 1  3081c02d-2747-4979-bec6-b835d1e69dd6  2017-01-30 17:00:00            BIG
# 2  3fb3fbd0-0812-4513-a7cd-450c72facd47  2017-01-15 14:45:00       FlipSid3
# 3  6896338b-bacb-4405-aaf2-3b79f8b323a3  2017-01-15 11:20:00         Heroic
# 4  f130d28e-adc9-42aa-bbed-d0b7688f474f  2017-01-14 19:30:00  Vega Squadron
# 5  1ecd175d-500c-458e-8de3-33275bf21c00  2017-01-14 13:20:00            BIG
# 6  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b  2017-01-13 14:30:00       FlipSid3
# 7  b200996b-da5f-47e0-95e9-07fc7359811a  2017-01-09 17:00:00    mousesports
#
#       team_b                                                url  \
# 0    iNation  https://www.hltv.org/matches/2307616/big-vs-in...
# 1  iGame.com  https://www.hltv.org/matches/2307615/big-vs-ig...
# 2        BIG  https://www.hltv.org/matches/2307440/flipsid3-...
# 3        BIG  https://www.hltv.org/matches/2307438/heroic-vs...
# 4        BIG  https://www.hltv.org/matches/2307437/vega-squa...
# 5      Rogue  https://www.hltv.org/matches/2307435/big-vs-ro...
# 6        BIG  https://www.hltv.org/matches/2307429/flipsid3-...
# 7        BIG  https://www.hltv.org/matches/2307302/mousespor...
#
#                                            stats_url  \
# 0  https://www.hltv.org/stats/matches/mapstatsid/...
# 1  https://www.hltv.org/stats/matches/mapstatsid/...
# 2  https://www.hltv.org/stats/matches/41029/flips...
# 3  https://www.hltv.org/stats/matches/41028/heroi...
# 4  https://www.hltv.org/stats/matches/41022/vega-...
# 5  https://www.hltv.org/stats/matches/41020/big-v...
# 6  https://www.hltv.org/stats/matches/mapstatsid/...
# 7  https://www.hltv.org/stats/matches/40917/mouse...
#
#                                    demo_url
# 0  https://www.hltv.org/download/demo/25537
# 1  https://www.hltv.org/download/demo/25536
# 2  https://www.hltv.org/download/demo/25576
# 3  https://www.hltv.org/download/demo/25575
# 4  https://www.hltv.org/download/demo/25573
# 5  https://www.hltv.org/download/demo/25571
# 6  https://www.hltv.org/download/demo/25565
# 7  https://www.hltv.org/download/demo/25558
