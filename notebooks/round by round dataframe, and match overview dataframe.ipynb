# %%
import cspython.scraper
import pandas as pd
import numpy as np
import uuid
import sys
sys.setrecursionlimit(15000)

# %%
series = cspython.scraper.scrape_series_data('BIG', '2017-01-01', '2017-02-01', verbose=False)
# Out:
# match 0 done
# match 1 done
# match 2 done
# match 3 done
# match 4 done
# match 5 done
# match 6 done
# match 7 done

# %%
series[2]['team_scoreboards'][0]
# Out:
# [                                  FlipSid3    K-D  +/-    ADR   KAST  \
#  0  Denis 'electronic' Sharipov  electronic  28-16   12  105.1  77.8%
#  1      Jan 'wayLander' Rahkonen  wayLander  26-19    7   94.7  74.1%
#  2    Yegor 'markeloff' Markelov  markeloff  18-17    1   77.4  74.1%
#  3     Georgi 'WorldEdit' Yaskin  WorldEdit  17-17    0   68.1  74.1%
#  4        Andrey 'B1ad3' Gorodenskiy  B1ad3  15-19   -4   70.9  77.8%
#
#     Rating2.0
#  0       1.60
#  1       1.43
#  2       1.10
#  3       1.08
#  4       1.00  ,
#                                    FlipSid3    K-D  +/-   ADR   KAST  Rating2.0
#  0  Denis 'electronic' Sharipov  electronic  26-15   11  99.3  85.2%       1.54
#  1    Yegor 'markeloff' Markelov  markeloff  20-13    7  79.9  74.1%       1.25
#  2        Andrey 'B1ad3' Gorodenskiy  B1ad3  21-19    2  70.2  77.8%       1.21
#  3     Georgi 'WorldEdit' Yaskin  WorldEdit  22-18    4  78.1  74.1%       1.07
#  4      Jan 'wayLander' Rahkonen  wayLander  14-18   -4  65.9  59.3%       0.89,
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
#  0  WorldEdit      B1ad3  markeloff  wayLander  electronic]

# %% [markdown]
# Each element of list returned by scrape_series_data is a dictionary containing data 1 series played by the team. They are in reverse chornological order. The elements of each series dictionary are:
#
#     url:        the url on hltv of the Overview of the entire series
#     demo_url:   the url of the demo, hosted on hltv later
#     stats_url:  a url containing more detailed data about the data
#                 (the scrapped data from this page is contained in stats_data)
#     teams:      a dataframe containing the overall stats for each team in the series
#     vetos:      the vetos in chronological order
#     match_info: score and map name for each match
#     team_a_b:   this provides order to the teams and match_info scores

# %%
def match_score_dataframe(series, series_id=None):
    score = pd.DataFrame(columns = ['series_id', 'match_id', 'map', 'winner', series['team_a_b'][0], 
                                    series['team_a_b'][1]], 
                         index=range(len(series['match_info'])))
    for idx, match in enumerate(series['match_info']):
        
        map_name = match['map_name']
        score_a = int(match['scores'][0])
        score_b = int(match['scores'][1])
        if score_a > score_b:
            winner = series['team_a_b'][0]
        elif score_a < score_b:
            winner = series['team_a_b'][1]
        else:
            winner = 'draw'
        match_id = uuid.uuid4()
        score.loc[idx, :]  = series_id, match_id, map_name, winner, score_a, score_b
        
        
    score.loc[:,'match_num'] = range(1,len(score) + 1)
    
    return score

# %%
def round_by_round_dataframe(match_stats_data, map_name, match_id, series_id):
    winners = create_winner_column(match_stats_data['team_scores'])
    team_ending_df = create_team_ending_df(match_stats_data['team_endings'], winners)
    raw = pd.concat([team_ending_df, winners], axis=1)
    final = pd.DataFrame(columns = ['map', 'round_num', 'half'], index=raw.index)
    final.loc[:,'map'] = map_name
    final.loc[:,'round_num']=raw.index
    final.ix[:16, 'half'] = 1
    final.ix[16:, 'half'] = 2
    final.loc[:, 'match_id'] = match_id
    final.loc[:, 'series_id'] = series_id
    return pd.concat([final, raw], axis=1)

# %%
def create_winner_column(team_scores):
    team_a = pd.Series(team_scores['team_a']).apply(lambda x: x[0])
    team_b = pd.Series(team_scores['team_b']).apply(lambda x: x[0])
    raw_scores = pd.concat([team_a, team_b], axis=1)
    raw_scores = raw_scores.loc[(raw_scores.loc[:,0]!='')|(raw_scores.loc[:,1]!=''), :]
    
    team_a = raw_scores.iloc[0,0]
    team_b = raw_scores.iloc[0,1]
    
    raw_scores = raw_scores.iloc[1:,:]
    
    winner_col = pd.DataFrame(columns=['winner', team_a + '_wins', team_b + '_wins'], index=raw_scores.index)
    w_a=0
    w_b=0
    for idx, row in raw_scores.iterrows():
        if row.iloc[0]=='':
            winner = team_b
            w_b+=1
        else:
            winner = team_a
            w_a+=1
        winner_col.loc[idx,['winner', team_a + '_wins', team_b + '_wins']] = winner, w_a, w_b
    return winner_col

def create_team_ending_df(team_endings, winners):
    team_a_name, team_b_name = winners.columns[1][:-5], winners.columns[2][:-5]
    
    team_a = pd.Series(team_endings['team_a']).apply(lambda x: x[0])
    team_b = pd.Series(team_endings['team_b']).apply(lambda x: x[0])
    raw_endings = pd.concat([team_a, team_b], axis=1)
    raw_endings = raw_endings.loc[(raw_endings.loc[:,0]!='emptyHistory')|(raw_endings.loc[:,1]!='emptyHistory'), :]
    raw_endings = raw_endings.iloc[1:,:]
    endings = pd.DataFrame(columns=['ending', 'CT', 'T', 'side_winner'], index=raw_endings.index)
    
    if (('t_win' in team_a.iloc[:16]) 
        or ('ct_win' in team_a.iloc[:16])
        or ('ct_win' in team_a.iloc[16:]) 
        or ('t_win' in team_a.iloc[16:])):
        endings.ix[:15, 'T'] = team_b_name
        endings.ix[:15, 'CT'] = team_a_name
        endings.ix[15:, 'T'] = team_a_name
        endings.ix[15:, 'CT'] = team_b_name
    else:
        endings.ix[:16, 'T'] = team_a_name
        endings.ix[:16, 'CT'] = team_b_name
        endings.ix[16:, 'T'] = team_b_name
        endings.ix[16:, 'CT'] = team_a_name
        
    endings.loc[:,'ending'] = raw_endings.apply(lambda x: x.iloc[0] if x.iloc[0] != 'emptyHistory' else x.iloc[1], axis=1)
    endings.loc[:, 'side_winner'] = endings.apply(lambda x: 'T' if x.loc['T'] == winners.loc[x.name, 'winner'] else 'CT', axis=1)
    return endings

# %%
def series_overview_dataframe(all_series):
    all_series_overview = pd.DataFrame(columns=['id', 'date', 'team_a', 
                                                'team_b', 'url', 'stats_url',
                                               'demo_url'])
    for s in all_series:
        demo_url = s['demo_url']
        stats_url = s['stats_url']
        url = s['url']
        date = s['stats_data'][0]['match_time']
        team_a = s['team_a_b'][0]
        team_b = s['team_a_b'][1]
        serires_uuid = uuid.uuid4()
        all_series_overview.loc[len(all_series_overview), :]= (
        serires_uuid, date, team_a, team_b, url, stats_url, demo_url )
        
    return all_series_overview

# %%
def process_scrapped(all_series):
    overview = series_overview_dataframe(all_series)
    series_data = {}
     
    for s_id, s in zip(overview.id, all_series):
        match_overview = match_score_dataframe(s, s_id)
        map_pool = s['map_pool']
        vetos = s['vetos']
        matches=[]
        for m_id, m, map_name in zip(match_overview.match_id, s['stats_data'], match_overview.map):
            df = round_by_round_dataframe(m, map_name, m_id, s_id)
            matches.append(df)
            
        series_data[s_id] = {
                      'match_overview': match_overview,
                      'map_pool': map_pool,
                      'vetos': vetos,
                      'scoreboards': s['team_scoreboards'],
                      'matches':matches}
    return overview, series_data

# %%
overview, series_data = process_scrapped(series)

# %%
overview.to_pickle('BIG_overview.pkl')

# %%
import cPickle as pkl
with open('BIG_Series_data.pkl', 'wb') as f:
    pkl.dump(series_data, f)

# %%
round_by_round_dataframe(series[0]['stats_data'][0], 'Dust')
# Out:
#      map  round_num half         ending       CT        T side_winner  \
# 1   Dust          1    1          t_win  iNation      BIG           T
# 2   Dust          2    1  bomb_exploded  iNation      BIG           T
# 3   Dust          3    1  bomb_exploded  iNation      BIG           T
# 4   Dust          4    1          t_win  iNation      BIG           T
# 5   Dust          5    1         ct_win  iNation      BIG          CT
# 6   Dust          6    1         ct_win  iNation      BIG          CT
# 7   Dust          7    1   bomb_defused  iNation      BIG          CT
# 8   Dust          8    1         ct_win  iNation      BIG          CT
# 9   Dust          9    1         ct_win  iNation      BIG          CT
# 10  Dust         10    1         ct_win  iNation      BIG          CT
# 11  Dust         11    1         ct_win  iNation      BIG          CT
# 12  Dust         12    1         ct_win  iNation      BIG          CT
# 13  Dust         13    1         ct_win  iNation      BIG          CT
# 14  Dust         14    1         ct_win  iNation      BIG          CT
# 15  Dust         15    2          t_win      BIG  iNation          CT
# 16  Dust         16    2   bomb_defused      BIG  iNation          CT
# 17  Dust         17    2         ct_win      BIG  iNation          CT
# 18  Dust         18    2         ct_win      BIG  iNation          CT
# 19  Dust         19    2         ct_win      BIG  iNation          CT
# 20  Dust         20    2         ct_win      BIG  iNation          CT
# 21  Dust         21    2          t_win      BIG  iNation           T
# 22  Dust         22    2         ct_win      BIG  iNation          CT
# 23  Dust         23    2   bomb_defused      BIG  iNation          CT
# 24  Dust         24    2         ct_win      BIG  iNation          CT
# 25  Dust         25    2          t_win      BIG  iNation           T
# 26  Dust         26    2          t_win      BIG  iNation           T
# 27  Dust         27    2  bomb_exploded      BIG  iNation           T
# 28  Dust         28    2          t_win      BIG  iNation           T
# 29  Dust         29    2          t_win      BIG  iNation           T
#
#      winner BIG_wins iNation_wins
# 1       BIG        1            0
# 2       BIG        2            0
# 3       BIG        3            0
# 4       BIG        4            0
# 5   iNation        4            1
# 6   iNation        4            2
# 7   iNation        4            3
# 8   iNation        4            4
# 9   iNation        4            5
# 10  iNation        4            6
# 11  iNation        4            7
# 12  iNation        4            8
# 13  iNation        4            9
# 14  iNation        4           10
# 15      BIG        5           10
# 16      BIG        6           10
# 17      BIG        7           10
# 18      BIG        8           10
# 19      BIG        9           10
# 20      BIG       10           10
# 21  iNation       10           11
# 22      BIG       11           11
# 23      BIG       12           11
# 24      BIG       13           11
# 25  iNation       13           12
# 26  iNation       13           13
# 27  iNation       13           14
# 28  iNation       13           15
# 29  iNation       13           16

# %%
pd.__version__
# Out:
# u'0.18.1'

# %%
with open('BIG_Series_data.pkl', 'rb') as f:
    d = pkl.load(f)

# %%
test = pd.Series([['hi'] for i in range(10)])
test
# Out:
# 0    [hi]
# 1    [hi]
# 2    [hi]
# 3    [hi]
# 4    [hi]
# 5    [hi]
# 6    [hi]
# 7    [hi]
# 8    [hi]
# 9    [hi]
# dtype: object

# %%
print test[0]
print test.apply(lambda x: x[0])
# Out:
# ['hi']
# 0    hi
# 1    hi
# 2    hi
# 3    hi
# 4    hi
# 5    hi
# 6    hi
# 7    hi
# 8    hi
# 9    hi
# dtype: object

# %%
test.apply(lambda x: x[0])
# Out:
# 0    hi
# 1    hi
# 2    hi
# 3    hi
# 4    hi
# 5    hi
# 6    hi
# 7    hi
# 8    hi
# 9    hi
# dtype: object

# %%
overview
# Out:
#                                      id                 date         team_a  \
# 0  9f427404-0a0f-42f3-a030-776cbb1ec929  2017-01-30 18:00:00            BIG
# 1  3081c02d-2747-4979-bec6-b835d1e69dd6  2017-01-30 17:00:00            BIG
# 2  3fb3fbd0-0812-4513-a7cd-450c72facd47  2017-01-15 14:45:00       FlipSid3
# 3  6896338b-bacb-4405-aaf2-3b79f8b323a3  2017-01-15 11:20:00         Heroic
# 4  f130d28e-adc9-42aa-bbed-d0b7688f474f  2017-01-14 19:30:00  Vega Squadron
# 5  1ecd175d-500c-458e-8de3-33275bf21c00  2017-01-14 13:20:00            BIG
# 6  53e95bb9-91bd-42d8-b7cf-59c4bdc2293b  2017-01-13 14:30:00       FlipSid3
# 7  b200996b-da5f-47e0-95e9-07fc7359811a  2017-01-09 17:00:00    mousesports
#
#       team_b                                                url  \
# 0    iNation  https://www.hltv.org/matches/2307616/big-vs-in...
# 1  iGame.com  https://www.hltv.org/matches/2307615/big-vs-ig...
# 2        BIG  https://www.hltv.org/matches/2307440/flipsid3-...
# 3        BIG  https://www.hltv.org/matches/2307438/heroic-vs...
# 4        BIG  https://www.hltv.org/matches/2307437/vega-squa...
# 5      Rogue  https://www.hltv.org/matches/2307435/big-vs-ro...
# 6        BIG  https://www.hltv.org/matches/2307429/flipsid3-...
# 7        BIG  https://www.hltv.org/matches/2307302/mousespor...
#
#                                            stats_url  \
# 0  https://www.hltv.org/stats/matches/mapstatsid/...
# 1  https://www.hltv.org/stats/matches/mapstatsid/...
# 2  https://www.hltv.org/stats/matches/41029/flips...
# 3  https://www.hltv.org/stats/matches/41028/heroi...
# 4  https://www.hltv.org/stats/matches/41022/vega-...
# 5  https://www.hltv.org/stats/matches/41020/big-v...
# 6  https://www.hltv.org/stats/matches/mapstatsid/...
# 7  https://www.hltv.org/stats/matches/40917/mouse...
#
#                                    demo_url
# 0  https://www.hltv.org/download/demo/25537
# 1  https://www.hltv.org/download/demo/25536
# 2  https://www.hltv.org/download/demo/25576
# 3  https://www.hltv.org/download/demo/25575
# 4  https://www.hltv.org/download/demo/25573
# 5  https://www.hltv.org/download/demo/25571
# 6  https://www.hltv.org/download/demo/25565
# 7  https://www.hltv.org/download/demo/25558

# %%
team_name = 'BIG'
startDate = '2017-07-19'
endDate = '2017-07-22'


bad_series = cspython.scraper.scrape_series_data(team_name, startDate, endDate, verbose=True, pkl_save=False)
# Out:
# https://www.hltv.org/results?offset=0&content=demo&team=7532&startDate=2017-07-19&endDate=2017-07-22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-df2a1905f5f4> in <module>()
#       4
#       5
# ----> 6 bad_series = cspython.scraper.scrape_series_data(team_name, startDate, endDate, verbose=True, pkl_save=False)
#
# c:\users\mckak\cs_stuff\cs_python\cspython\scraper.py in scrape_series_data(team_name, startDate, endDate, verbose, pkl_save)
#     362         'endDate':endDate
#     363     }
# --> 364     urls_bof = get_matches_result_page_urls_bof(params)
#     365     all_series = scrape(parse_all_match_data,urls_bof, pkl_save)
#     366     return all_series
#
# c:\users\mckak\cs_stuff\cs_python\cspython\scraper.py in get_matches_result_page_urls_bof(params)
#      75     bof = []
#      76     while not done:
# ---> 77         matches = get_matches_result_page_soup(params)
#      78         if len(matches) == 0:
#      79             break
#
# c:\users\mckak\cs_stuff\cs_python\cspython\scraper.py in get_matches_result_page_soup(params)
#      47     match_page = "https://www.hltv.org/results?offset={offset}&content=demo&team={teamID}&startDate={" \
#      48                  "startDate}&endDate={endDate}".format(**params)
# ---> 49     soup = get_soup(match_page)
#      50     matches_soup = soup.find_all("div", class_='results-all')
#      51     return matches_soup
#
# c:\users\mckak\cs_stuff\cs_python\cspython\scraper.py in get_soup(url)
#      31     if VERBOSE_URL:
#      32         print soup._url
# ---> 33     time.sleep(5)
#      34     return soup
#      35
#
# KeyboardInterrupt:

# %%
bad_series = [bad_series]

# %%
ov, d = process_scrapped(bad_series)

# %%
d
# Out:
# {UUID('2a6ea5c6-5214-4b07-9840-963c85298ee9'): {'map_pool': [u'Cache',
#    u'Mirage',
#    u'Inferno',
#    u'Nuke',
#    u'Train',
#    u'Cobblestone',
#    u'Overpass'],
#   'match_overview':                               series_id                              match_id  \
#   0  2a6ea5c6-5214-4b07-9840-963c85298ee9  3a17c507-cd55-40ef-ba66-0959e247f718
#   1  2a6ea5c6-5214-4b07-9840-963c85298ee9  06432f41-32d3-4141-aaec-a99d41a4d303
#   2  2a6ea5c6-5214-4b07-9840-963c85298ee9  33800a4b-8bb5-4066-995e-07c74784d43d
#
#              map     winner BIG Immortals  match_num
#   0  Cobblestone        BIG  19        17          1
#   1      Inferno  Immortals   7        16          2
#   2        Train  Immortals  14        16          3  ,
#   'matches': [            map  round_num half                              match_id  \
#    1   Cobblestone          1    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    2   Cobblestone          2    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    3   Cobblestone          3    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    4   Cobblestone          4    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    5   Cobblestone          5    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    6   Cobblestone          6    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    7   Cobblestone          7    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    8   Cobblestone          8    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    9   Cobblestone          9    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    10  Cobblestone         10    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    11  Cobblestone         11    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    12  Cobblestone         12    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    13  Cobblestone         13    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    14  Cobblestone         14    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    15  Cobblestone         15    1  3a17c507-cd55-40ef-ba66-0959e247f718
#    16  Cobblestone         16    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    17  Cobblestone         17    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    18  Cobblestone         18    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    19  Cobblestone         19    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    20  Cobblestone         20    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    21  Cobblestone         21    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    22  Cobblestone         22    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    23  Cobblestone         23    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    24  Cobblestone         24    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    25  Cobblestone         25    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    26  Cobblestone         26    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    27  Cobblestone         27    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    28  Cobblestone         28    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    29  Cobblestone         29    2  3a17c507-cd55-40ef-ba66-0959e247f718
#    30  Cobblestone         30    2  3a17c507-cd55-40ef-ba66-0959e247f718
#
#                                   series_id         ending         CT          T  \
#    1   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    2   2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    3   2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    4   2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    5   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    6   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    7   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    8   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    9   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    10  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    11  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    12  2a6ea5c6-5214-4b07-9840-963c85298ee9      stopwatch  Immortals        BIG
#    13  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    14  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    15  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    16  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    17  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    18  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    19  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    20  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    21  2a6ea5c6-5214-4b07-9840-963c85298ee9      stopwatch        BIG  Immortals
#    22  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    23  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    24  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    25  2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded        BIG  Immortals
#    26  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    27  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    28  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    29  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    30  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#
#       side_winner     winner BIG_wins Immortals_wins
#    1           CT  Immortals        0              1
#    2            T        BIG        1              1
#    3            T        BIG        2              1
#    4            T        BIG        3              1
#    5           CT  Immortals        3              2
#    6           CT  Immortals        3              3
#    7           CT  Immortals        3              4
#    8           CT  Immortals        3              5
#    9           CT  Immortals        3              6
#    10          CT  Immortals        3              7
#    11          CT  Immortals        3              8
#    12          CT  Immortals        3              9
#    13          CT  Immortals        3             10
#    14          CT  Immortals        3             11
#    15          CT  Immortals        3             12
#    16          CT        BIG        4             12
#    17          CT        BIG        5             12
#    18          CT        BIG        6             12
#    19          CT        BIG        7             12
#    20          CT        BIG        8             12
#    21          CT        BIG        9             12
#    22           T  Immortals        9             13
#    23          CT        BIG       10             13
#    24          CT        BIG       11             13
#    25           T  Immortals       11             14
#    26          CT        BIG       12             14
#    27          CT        BIG       13             14
#    28          CT        BIG       14             14
#    29          CT        BIG       15             14
#    30           T  Immortals       15             15  ,
#            map  round_num half                              match_id  \
#    1   Inferno          1    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    2   Inferno          2    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    3   Inferno          3    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    4   Inferno          4    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    5   Inferno          5    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    6   Inferno          6    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    7   Inferno          7    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    8   Inferno          8    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    9   Inferno          9    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    10  Inferno         10    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    11  Inferno         11    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    12  Inferno         12    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    13  Inferno         13    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    14  Inferno         14    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    15  Inferno         15    1  06432f41-32d3-4141-aaec-a99d41a4d303
#    16  Inferno         16    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    17  Inferno         17    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    18  Inferno         18    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    19  Inferno         19    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    20  Inferno         20    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    21  Inferno         21    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    22  Inferno         22    2  06432f41-32d3-4141-aaec-a99d41a4d303
#    23  Inferno         23    2  06432f41-32d3-4141-aaec-a99d41a4d303
#
#                                   series_id         ending         CT          T  \
#    1   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    2   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    3   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    4   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    5   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    6   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    7   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    8   2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    9   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    10  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    11  2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    12  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    13  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    14  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    15  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    16  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    17  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    18  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    19  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    20  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    21  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    22  2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused        BIG  Immortals
#    23  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#
#       side_winner     winner BIG_wins Immortals_wins
#    1           CT  Immortals        0              1
#    2           CT  Immortals        0              2
#    3           CT  Immortals        0              3
#    4           CT  Immortals        0              4
#    5           CT  Immortals        0              5
#    6           CT  Immortals        0              6
#    7           CT  Immortals        0              7
#    8            T        BIG        1              7
#    9           CT  Immortals        1              8
#    10          CT  Immortals        1              9
#    11          CT  Immortals        1             10
#    12          CT  Immortals        1             11
#    13          CT  Immortals        1             12
#    14           T        BIG        2             12
#    15          CT  Immortals        2             13
#    16           T  Immortals        2             14
#    17           T  Immortals        2             15
#    18          CT        BIG        3             15
#    19          CT        BIG        4             15
#    20          CT        BIG        5             15
#    21          CT        BIG        6             15
#    22          CT        BIG        7             15
#    23           T  Immortals        7             16  ,
#          map  round_num half                              match_id  \
#    1   Train          1    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    2   Train          2    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    3   Train          3    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    4   Train          4    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    5   Train          5    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    6   Train          6    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    7   Train          7    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    8   Train          8    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    9   Train          9    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    10  Train         10    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    11  Train         11    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    12  Train         12    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    13  Train         13    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    14  Train         14    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    15  Train         15    1  33800a4b-8bb5-4066-995e-07c74784d43d
#    16  Train         16    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    17  Train         17    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    18  Train         18    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    19  Train         19    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    20  Train         20    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    21  Train         21    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    22  Train         22    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    23  Train         23    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    24  Train         24    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    25  Train         25    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    26  Train         26    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    27  Train         27    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    28  Train         28    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    29  Train         29    2  33800a4b-8bb5-4066-995e-07c74784d43d
#    30  Train         30    2  33800a4b-8bb5-4066-995e-07c74784d43d
#
#                                   series_id         ending         CT          T  \
#    1   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    2   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    3   2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    4   2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    5   2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    6   2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    7   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    8   2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    9   2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    10  2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    11  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win  Immortals        BIG
#    12  2a6ea5c6-5214-4b07-9840-963c85298ee9   bomb_defused  Immortals        BIG
#    13  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    14  2a6ea5c6-5214-4b07-9840-963c85298ee9  bomb_exploded  Immortals        BIG
#    15  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win  Immortals        BIG
#    16  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    17  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    18  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    19  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    20  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    21  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    22  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    23  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    24  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    25  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    26  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    27  2a6ea5c6-5214-4b07-9840-963c85298ee9         ct_win        BIG  Immortals
#    28  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    29  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#    30  2a6ea5c6-5214-4b07-9840-963c85298ee9          t_win        BIG  Immortals
#
#       side_winner     winner BIG_wins Immortals_wins
#    1           CT  Immortals        0              1
#    2           CT  Immortals        0              2
#    3           CT  Immortals        0              3
#    4            T        BIG        1              3
#    5            T        BIG        2              3
#    6            T        BIG        3              3
#    7           CT  Immortals        3              4
#    8           CT  Immortals        3              5
#    9            T        BIG        4              5
#    10           T        BIG        5              5
#    11           T        BIG        6              5
#    12          CT  Immortals        6              6
#    13          CT  Immortals        6              7
#    14           T        BIG        7              7
#    15          CT  Immortals        7              8
#    16           T  Immortals        7              9
#    17          CT        BIG        8              9
#    18          CT        BIG        9              9
#    19          CT        BIG       10              9
#    20          CT        BIG       11              9
#    21          CT        BIG       12              9
#    22           T  Immortals       12             10
#    23          CT        BIG       13             10
#    24           T  Immortals       13             11
#    25           T  Immortals       13             12
#    26           T  Immortals       13             13
#    27          CT        BIG       14             13
#    28           T  Immortals       14             14
#    29           T  Immortals       14             15
#    30           T  Immortals       14             16  ],
#   'scoreboards': [[                                BIG    K-D  +/-   ADR   KAST  Rating2.0
#     0     Nikola 'LEGIJA' Ninić  LEGIJA  35-23   12  92.8  83.3%       1.51
#     1  Johannes 'tabseN' Wodarz  tabseN  28-26    2  92.6  69.4%       1.23
#     2         Johannes 'nex' Maget  nex  24-23    1  89.7  75.0%       1.16
#     3   Kevin 'keev' Bartholomäus  keev  25-19    6  55.8  69.4%       0.98
#     4        Fatih 'gob b' Dayik  gob b  21-23   -2  71.9  69.4%       0.97,
#                                     BIG    K-D  +/-   ADR   KAST  Rating2.0
#     0     Nikola 'LEGIJA' Ninić  LEGIJA  19-19    0  82.9  60.9%       0.98
#     1  Johannes 'tabseN' Wodarz  tabseN  10-20  -10  63.7  56.5%       0.81
#     2   Kevin 'keev' Bartholomäus  keev  12-19   -7  56.1  52.2%       0.79
#     3        Fatih 'gob b' Dayik  gob b   9-18   -9  71.8  60.9%       0.73
#     4         Johannes 'nex' Maget  nex  13-19   -6  57.8  60.9%       0.70,
#                                     BIG    K-D  +/-   ADR   KAST  Rating2.0
#     0  Johannes 'tabseN' Wodarz  tabseN  31-20   11  95.1  76.7%       1.41
#     1         Johannes 'nex' Maget  nex  22-19    3  83.1  80.0%       1.14
#     2     Nikola 'LEGIJA' Ninić  LEGIJA  19-18    1  78.8  73.3%       1.06
#     3   Kevin 'keev' Bartholomäus  keev  17-16    1  63.9  66.7%       1.00
#     4        Fatih 'gob b' Dayik  gob b  17-22   -5  48.8  66.7%       0.80,
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
#     0      gob b     LEGIJA     tabseN        nex       keev],
#    [                      Immortals    K-D  +/-   ADR   KAST  Rating2.0
#     0    Lucas 'steel' Lopes  steel  31-26    5  93.5  69.4%       1.18
#     1  Vito 'kNgV-' Giuseppe  kNgV-  28-27    1  84.6  63.9%       1.17
#     2  Lucas 'LUCAS1' Teles  LUCAS1  21-28   -7  83.7  66.7%       0.94
#     3  Ricardo 'boltz' Prass  boltz  21-25   -4  53.6  63.9%       0.77
#     4   Henrique 'HEN1' Teles  HEN1  13-27  -14  56.1  58.3%       0.71,
#                           Immortals    K-D  +/-    ADR   KAST  Rating2.0
#     0    Lucas 'steel' Lopes  steel  23-10   13   98.4  91.3%       1.63
#     1  Vito 'kNgV-' Giuseppe  kNgV-  25-15   10   92.3  78.3%       1.44
#     2  Lucas 'LUCAS1' Teles  LUCAS1  20-16    4  103.6  78.3%       1.26
#     3   Henrique 'HEN1' Teles  HEN1  13-12    1   79.8  73.9%       1.19
#     4  Ricardo 'boltz' Prass  boltz  13-10    3   62.2  78.3%       1.13,
#                           Immortals    K-D  +/-    ADR   KAST  Rating2.0
#     0  Ricardo 'boltz' Prass  boltz  24-21    3  101.7  80.0%       1.39
#     1   Henrique 'HEN1' Teles  HEN1  21-20    1   75.6  56.7%       1.02
#     2  Vito 'kNgV-' Giuseppe  kNgV-  21-21    0   64.4  60.0%       0.94
#     3    Lucas 'steel' Lopes  steel  15-21   -6   67.0  60.0%       0.88
#     4  Lucas 'LUCAS1' Teles  LUCAS1  14-23   -9   64.2  60.0%       0.78]],
#   'vetos': [u'1. Immortals removed Nuke',
#    u'2. BIG removed Overpass',
#    u'3. Immortals picked Cobblestone',
#    u'4. BIG picked Inferno',
#    u'5. BIG removed Mirage',
#    u'6. Immortals removed Cache',
#    u'7. Train was left over']}}

# %%
import cPickle as pkl
with open('test_pkl.pkl', 'wb') as f:
    pkl.dump(d, f)
