# %%
from cspython.scraper import modifiedSoup
from cspython.data_processing import process_scrapped
import cPickle as pkl
import sys
sys.setrecursionlimit(15000)
import pandas as pd

# %%
with open('../scrapped_data/Cloud9_11_16_to_10_17.pkl', 'rb') as f:
    d = pkl.load(f)
    
big_data = process_scrapped(d)
overview, big_data = big_data

# %%
overview
# Out:
#                                        id                 date      team_a  \
# 0    43ace678-fbca-4079-9cf5-24f62407dd86  2017-10-12 18:20:00      Cloud9
# 1    2ea4e486-799f-4168-8c9f-b0b11b2363ec  2017-10-11 21:10:00      Liquid
# 2    f92e4938-73c5-414b-89e7-40a11f84e481  2017-10-10 18:25:00          G2
# 3    058c880e-8681-4025-b712-24f436668e52  2017-10-07 23:55:00      Cloud9
# 4    381e7d85-a4ba-4c99-b214-9e52bb4645d3  2017-10-07 23:05:00  Luminosity
# 5    1af5965b-9908-4347-be7f-7b3d42065ab6  2017-10-07 19:40:00       OpTic
# 6    5f30b9bc-d025-452c-9812-4eb453b088e1  2017-10-06 23:10:00       OpTic
# 7    943a17e8-68c9-46d5-ae49-7afca1e9cb5b  2017-10-06 22:10:00      Cloud9
# 8    f421e652-5ded-4f58-a738-81c1148620bf  2017-10-06 00:40:00       Rogue
# 9    a9818097-43b7-4b16-bc7f-882d02b44686  2017-10-05 23:10:00      Cloud9
# 10   cec15166-d1ca-4e57-a9cd-9d3fa64f5d4d  2017-10-05 20:00:00      Cloud9
# ...

# %%
overview.keys()
# Out:
# Index([u'id', u'date', u'team_a', u'team_b', u'url', u'stats_url',
#        u'demo_url'],
#       dtype='object')

# %%
big_data.keys()
# Out:
# ['6676738d-9d89-433c-ada0-4cfcc19de92c',
#  '943a17e8-68c9-46d5-ae49-7afca1e9cb5b',
#  'fbe12368-cb7d-4b5b-b7f2-4843d4d219e9',
#  '75ab220f-aaaf-436b-be99-2043f3d375a9',
#  '48c7fdc8-532b-4f57-96e4-7db8e0611f43',
#  '266244bb-7732-4ac9-b662-830bb7aca134',
#  '4f3c585c-1eee-44b9-9b50-0fa75c53a75e',
#  '94618b5e-a9c0-4f01-8c81-1266273a8395',
#  '4352bc58-e6b6-4b20-93d0-be9760eca07e',
#  '51953ad1-1289-45bd-9896-a2c7902a9991',
#  'be0de62b-e29f-48a8-92ab-6514eff55d40',
#  '684a47bb-302b-4474-8300-8c6d2e4ab325',
#  'b4d808df-783f-465a-981a-cc57145035c6',
#  '4b244b10-847e-428c-a0e9-c680f58d236a',
#  'fea33ba7-3c5d-4fbc-95fe-5460cd4f8b6b',
#  '7a712214-b4a7-468d-988f-0ec53636655f',
#  '07fa57d2-75b0-4613-a068-4bd9c9306e2b',
#  'f4f0ed8b-bf1c-4b40-9575-441ad8c12bc3',
#  '916162da-db4a-4a1c-a77e-8c367dab36a1',
#  '081927ca-914d-47fc-8932-0156b49dd583',
#  '23a15ffc-f25b-4786-b54e-5bca4d38637c',
#  '0d8375d3-8a3e-4b71-8b00-979c5f5fece0',
#  '43ace678-fbca-4079-9cf5-24f62407dd86',
# ...

# %%
len(big_data) + sum(len(v) for v in big_data.itervalues())
# Out:
# 966

# %%
len(big_data)
# Out:
# 161

# %%
big_data['d9c236fb-21ec-4398-a581-01bf06e26aea']
# Out:
# {'map_pool': [u'Cache',
#   u'Mirage',
#   u'Inferno',
#   u'Nuke',
#   u'Train',
#   u'Cobblestone',
#   u'Overpass'],
#  'match_overview':                               series_id                              match_id  \
#  0  d9c236fb-21ec-4398-a581-01bf06e26aea  d891fe6f-aad0-4d17-91a8-25dd4ee8010e
#  1  d9c236fb-21ec-4398-a581-01bf06e26aea  89fb6694-c47f-49e9-ab89-6ab34a7905b6
#  2  d9c236fb-21ec-4398-a581-01bf06e26aea  197af41c-e9d5-47dd-a299-551ba9f3247a
#
#             map       winner Cloud9 Rise Nation  match_num
#  0  Cobblestone       Cloud9     16           3          1
#  1       Mirage  Rise Nation      9          16          2
#  2      Inferno       Cloud9     16           2          3  ,
#  'matches': [            map  round_num half                              match_id  \
#   1   Cobblestone          1    1  d891fe6f-aad0-4d17-91a8-25dd4ee8010e
#   2   Cobblestone          2    1  d891fe6f-aad0-4d17-91a8-25dd4ee8010e
# ...

# %%
big_data['684a47bb-302b-4474-8300-8c6d2e4ab325']['matches'][0]
# Out:
#        map  round_num half                              match_id  \
# 1   Mirage          1    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 2   Mirage          2    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 3   Mirage          3    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 4   Mirage          4    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 5   Mirage          5    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 6   Mirage          6    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 7   Mirage          7    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 8   Mirage          8    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 9   Mirage          9    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 10  Mirage         10    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 11  Mirage         11    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 12  Mirage         12    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# 13  Mirage         13    1  33a3c72d-8846-4c04-82d2-93d2b519f0c6
# ...

# %%
len(big_data['d9c236fb-21ec-4398-a581-01bf06e26aea']['match_overview'])
# Out:
# 3

# %%
 matches = big_data['d9c236fb-21ec-4398-a581-01bf06e26aea']['match_overview'][0:3]

# %%
matches
# Out:
#                               series_id                              match_id  \
# 0  d9c236fb-21ec-4398-a581-01bf06e26aea  d891fe6f-aad0-4d17-91a8-25dd4ee8010e
# 1  d9c236fb-21ec-4398-a581-01bf06e26aea  89fb6694-c47f-49e9-ab89-6ab34a7905b6
# 2  d9c236fb-21ec-4398-a581-01bf06e26aea  197af41c-e9d5-47dd-a299-551ba9f3247a
#
#            map       winner Cloud9 Rise Nation  match_num
# 0  Cobblestone       Cloud9     16           3          1
# 1       Mirage  Rise Nation      9          16          2
# 2      Inferno       Cloud9     16           2          3

# %%
matches = len(big_data['d9c236fb-21ec-4398-a581-01bf06e26aea']['match_overview']) 
for i in range(0, len(matches))
    data = data.append(big)
# Out:
# 3

# %%
data = pd.DataFrame()

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for key in big_data.keys():
    for win in big_data[key]['match_overview']
    data = data.append(big_data[key]['match_overview'])

# %%
data[['Cloud9']['SK']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-d2c5c8a26037> in <module>()
# ----> 1 data[['Cloud9']['SK']]
#
# TypeError: list indices must be integers, not str

# %%
test = data.groupby('winner')['map'].count()

# %%
test
# Out:
# winner
# Astralis           2
# BIG                1
# CLG                3
# Cloud9           130
# EnVyUs             1
# FaZe               7
# G2                 4
# Gambit             4
# HellRaisers        1
# Immortals         11
# L4Org              1
# Liquid             7
# Luminosity         3
# Misfits            1
# NRG                3
# Natus Vincere      2
# NiP                5
# North              4
# OpTic              5
# Renegades          3
# Rise Nation        1
# SK                15
# TyLoo              1
# Virtus.pro         2
# fnatic             2
# Name: map, dtype: int64

# %%
data['winner']
# Out:
# 0           Cloud9
# 0           Cloud9
# 0           Liquid
# 0               SK
# 0           Cloud9
# 1           Cloud9
# 0           Cloud9
# 0           Cloud9
# 0               SK
# 0           Cloud9
# 0           Cloud9
# 0             FaZe
# 0        Immortals
# 0               SK
# 0       Virtus.pro
# 0              BIG
# 0           Cloud9
# 1           Cloud9
# 0           Liquid
# 0            L4Org
# 1           Cloud9
# 2           Cloud9
# 0           Cloud9
# 1           Cloud9
# 0              CLG
# 0           Cloud9
# 0           Cloud9
# 0           Cloud9
# 1         Astralis
# 2         Astralis
#          ...
# 0             FaZe
# 1             FaZe
# 0           Cloud9
# 0      HellRaisers
# 0           Cloud9
# 0       Luminosity
# 0              NRG
# 0           Cloud9
# 0             FaZe
# 1             FaZe
# 0           Liquid
# 1           Liquid
# 0           EnVyUs
# 0        Immortals
# 1        Immortals
# 0           Cloud9
# ...

# %%
series = big_data['684a47bb-302b-4474-8300-8c6d2e4ab325']['match_overview']

# %%
series
# Out:
#                               series_id                              match_id  \
# 0  684a47bb-302b-4474-8300-8c6d2e4ab325  33a3c72d-8846-4c04-82d2-93d2b519f0c6
#
#       map     winner Immortals Cloud9  match_num
# 0  Mirage  Immortals        16      8          1

# %%
big_data['fbe12368-cb7d-4b5b-b7f2-4843d4d219e9']['match_overview'][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-6e701b0e1ca3> in <module>()
# ----> 1 big_data['fbe12368-cb7d-4b5b-b7f2-4843d4d219e9']['match_overview'][1]
#
# C:\Users\SuperBug\Anaconda2\envs\cs_project\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\SuperBug\Anaconda2\envs\cs_project\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
for match_overview in bigdata[key]['match_overview']:
            match_overview.get(info, False)
# Out:
#   File "<ipython-input-100-841bf0848f05>", line 1
#     for match_overview in bigdata[key]['match_overview']
#                                                         ^
# SyntaxError: invalid syntax
